# %%
# !pip install opendatasets
# import opendatasets as od
# od.download("https://www.kaggle.com/competitions/cpe-ai-hackathon-2025-medical-data-classification")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
train = pd.read_csv("/content/cpe-ai-hackathon-2025-medical-data-classification/train.csv")
test = pd.read_csv("/content/cpe-ai-hackathon-2025-medical-data-classification/test.csv")

# %%
train = train.drop(columns='id')
id_test = test.id
test = test.drop(columns='id')
test = test.drop(columns='Class')

# %%
train = train.fillna(train.median())
test = test.fillna(test.median())

x_train = train.drop(columns=['Class'])
y_train = train.Class

# %%
x_train = x_train.values.astype(np.float32)
tensor_x_train = torch.tensor(x_train)
y_train = y_train.values.astype(np.float32).reshape(-1, 1)
tensor_y_train = torch.tensor(y_train)

test = test.values.astype(np.float32)
tensor_test = torch.tensor(test)

# %%
class neural_network(nn.Module):
    def __init__(self, input_dim, output_dim=1, hidden_dims=[256, 128, 64, 32], dropout_rate=0.25):
        super(neural_network, self).__init__()

        self.input_bn = nn.BatchNorm1d(input_dim)

        layers = []
        in_dim = input_dim

        for h_dim in hidden_dims:
            layers.append(nn.Linear(in_dim, h_dim))
            layers.append(nn.BatchNorm1d(h_dim))
            layers.append(nn.LeakyReLU(negative_slope=0.1))
            layers.append(nn.Dropout(dropout_rate))
            in_dim = h_dim

        self.output_layer = nn.Linear(in_dim, output_dim)
        self.layers = nn.Sequential(*layers)
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.kaiming_normal_(m.weight, nonlinearity='leaky_relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = self.input_bn(x)
        out = self.layers(x)
        out = self.output_layer(out)

        return out

# %%
model = neural_network(tensor_x_train.shape[1])
pos_weight = torch.tensor([3.0])
error = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
optimizer = optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5)

col_F1, col_F1_val = [], []
epoch, n = 2000, 5

for i in range(0, epoch):
  model.train()
  y_hat = model(tensor_x_train)
  loss_BCE = error(y_hat, tensor_y_train)

  optimizer.zero_grad()
  loss_BCE.backward()
  optimizer.step()

  with torch.no_grad():
    y_hat = (y_hat >= 0.5).float()

  if i == (n-1):
    print(f"Epoch [{i+1}/{epoch}] | Loss(BCE): {loss_BCE:.4f}")
    n += 1
# Out:
# Epoch [5/2000] | Loss(BCE): 1.1065
# Epoch [6/2000] | Loss(BCE): 1.0731
# Epoch [7/2000] | Loss(BCE): 1.0375
# Epoch [8/2000] | Loss(BCE): 0.9950
# Epoch [9/2000] | Loss(BCE): 0.9727
# Epoch [10/2000] | Loss(BCE): 0.9551
# Epoch [11/2000] | Loss(BCE): 0.9406
# Epoch [12/2000] | Loss(BCE): 0.9292
# Epoch [13/2000] | Loss(BCE): 0.8964
# Epoch [14/2000] | Loss(BCE): 0.8682
# Epoch [15/2000] | Loss(BCE): 0.8681
# Epoch [16/2000] | Loss(BCE): 0.8448
# Epoch [17/2000] | Loss(BCE): 0.8210
# Epoch [18/2000] | Loss(BCE): 0.7915
# Epoch [19/2000] | Loss(BCE): 0.7911
# Epoch [20/2000] | Loss(BCE): 0.7619
# Epoch [21/2000] | Loss(BCE): 0.7622
# Epoch [22/2000] | Loss(BCE): 0.7456
# Epoch [23/2000] | Loss(BCE): 0.7267
# Epoch [24/2000] | Loss(BCE): 0.7152
# Epoch [25/2000] | Loss(BCE): 0.6951
# Epoch [26/2000] | Loss(BCE): 0.6980
# Epoch [27/2000] | Loss(BCE): 0.6799
# Epoch [28/2000] | Loss(BCE): 0.6731
# Epoch [29/2000] | Loss(BCE): 0.6621
# Epoch [30/2000] | Loss(BCE): 0.6554
# Epoch [31/2000] | Loss(BCE): 0.6467
# Epoch [32/2000] | Loss(BCE): 0.6319
# Epoch [33/2000] | Loss(BCE): 0.6269
# Epoch [34/2000] | Loss(BCE): 0.6285
# Epoch [35/2000] | Loss(BCE): 0.6170
# Epoch [36/2000] | Loss(BCE): 0.6221
# Epoch [37/2000] | Loss(BCE): 0.5997
# Epoch [38/2000] | Loss(BCE): 0.5935
# Epoch [39/2000] | Loss(BCE): 0.5823
# Epoch [40/2000] | Loss(BCE): 0.5663
# Epoch [41/2000] | Loss(BCE): 0.5797
# Epoch [42/2000] | Loss(BCE): 0.5628
# Epoch [43/2000] | Loss(BCE): 0.5585
# Epoch [44/2000] | Loss(BCE): 0.5433
# Epoch [45/2000] | Loss(BCE): 0.5351
# Epoch [46/2000] | Loss(BCE): 0.5332
# Epoch [47/2000] | Loss(BCE): 0.5291
# Epoch [48/2000] | Loss(BCE): 0.5168
# Epoch [49/2000] | Loss(BCE): 0.5106
# Epoch [50/2000] | Loss(BCE): 0.5121
# Epoch [51/2000] | Loss(BCE): 0.5039
# Epoch [52/2000] | Loss(BCE): 0.4978
# Epoch [53/2000] | Loss(BCE): 0.4777
# Epoch [54/2000] | Loss(BCE): 0.4785
# Epoch [55/2000] | Loss(BCE): 0.4903
# Epoch [56/2000] | Loss(BCE): 0.4743
# Epoch [57/2000] | Loss(BCE): 0.4621
# Epoch [58/2000] | Loss(BCE): 0.4651
# Epoch [59/2000] | Loss(BCE): 0.4558
# Epoch [60/2000] | Loss(BCE): 0.4356
# Epoch [61/2000] | Loss(BCE): 0.4457
# Epoch [62/2000] | Loss(BCE): 0.4355
# Epoch [63/2000] | Loss(BCE): 0.4438
# Epoch [64/2000] | Loss(BCE): 0.4306
# Epoch [65/2000] | Loss(BCE): 0.4222
# Epoch [66/2000] | Loss(BCE): 0.4158
# Epoch [67/2000] | Loss(BCE): 0.4225
# Epoch [68/2000] | Loss(BCE): 0.4037
# Epoch [69/2000] | Loss(BCE): 0.4137
# Epoch [70/2000] | Loss(BCE): 0.4022
# Epoch [71/2000] | Loss(BCE): 0.3961
# Epoch [72/2000] | Loss(BCE): 0.3947
# Epoch [73/2000] | Loss(BCE): 0.3917
# Epoch [74/2000] | Loss(BCE): 0.3933
# Epoch [75/2000] | Loss(BCE): 0.3837
# Epoch [76/2000] | Loss(BCE): 0.3663
# Epoch [77/2000] | Loss(BCE): 0.3682
# Epoch [78/2000] | Loss(BCE): 0.3675
# Epoch [79/2000] | Loss(BCE): 0.3615
# Epoch [80/2000] | Loss(BCE): 0.3541
# Epoch [81/2000] | Loss(BCE): 0.3637
# Epoch [82/2000] | Loss(BCE): 0.3438
# Epoch [83/2000] | Loss(BCE): 0.3536
# Epoch [84/2000] | Loss(BCE): 0.3470
# Epoch [85/2000] | Loss(BCE): 0.3444
# Epoch [86/2000] | Loss(BCE): 0.3347
# Epoch [87/2000] | Loss(BCE): 0.3349
# Epoch [88/2000] | Loss(BCE): 0.3391
# Epoch [89/2000] | Loss(BCE): 0.3286
# Epoch [90/2000] | Loss(BCE): 0.3290
# Epoch [91/2000] | Loss(BCE): 0.3249
# Epoch [92/2000] | Loss(BCE): 0.3181
# Epoch [93/2000] | Loss(BCE): 0.3256
# Epoch [94/2000] | Loss(BCE): 0.3054
# Epoch [95/2000] | Loss(BCE): 0.3212
# Epoch [96/2000] | Loss(BCE): 0.3102
# Epoch [97/2000] | Loss(BCE): 0.3191
# Epoch [98/2000] | Loss(BCE): 0.3102
# Epoch [99/2000] | Loss(BCE): 0.3037
# Epoch [100/2000] | Loss(BCE): 0.3024
# Epoch [101/2000] | Loss(BCE): 0.2922
# Epoch [102/2000] | Loss(BCE): 0.3077
# Epoch [103/2000] | Loss(BCE): 0.2958
# Epoch [104/2000] | Loss(BCE): 0.2928
# Epoch [105/2000] | Loss(BCE): 0.2922
# Epoch [106/2000] | Loss(BCE): 0.2927
# Epoch [107/2000] | Loss(BCE): 0.2813
# Epoch [108/2000] | Loss(BCE): 0.2882
# Epoch [109/2000] | Loss(BCE): 0.2963
# Epoch [110/2000] | Loss(BCE): 0.2838
# Epoch [111/2000] | Loss(BCE): 0.2871
# Epoch [112/2000] | Loss(BCE): 0.2742
# Epoch [113/2000] | Loss(BCE): 0.2620
# Epoch [114/2000] | Loss(BCE): 0.2723
# Epoch [115/2000] | Loss(BCE): 0.2706
# Epoch [116/2000] | Loss(BCE): 0.2792
# Epoch [117/2000] | Loss(BCE): 0.2595
# Epoch [118/2000] | Loss(BCE): 0.2522
# Epoch [119/2000] | Loss(BCE): 0.2571
# Epoch [120/2000] | Loss(BCE): 0.2589
# Epoch [121/2000] | Loss(BCE): 0.2479
# Epoch [122/2000] | Loss(BCE): 0.2573
# Epoch [123/2000] | Loss(BCE): 0.2523
# Epoch [124/2000] | Loss(BCE): 0.2550
# Epoch [125/2000] | Loss(BCE): 0.2424
# Epoch [126/2000] | Loss(BCE): 0.2553
# Epoch [127/2000] | Loss(BCE): 0.2410
# Epoch [128/2000] | Loss(BCE): 0.2539
# Epoch [129/2000] | Loss(BCE): 0.2463
# Epoch [130/2000] | Loss(BCE): 0.2390
# Epoch [131/2000] | Loss(BCE): 0.2383
# Epoch [132/2000] | Loss(BCE): 0.2351
# Epoch [133/2000] | Loss(BCE): 0.2328
# Epoch [134/2000] | Loss(BCE): 0.2280
# Epoch [135/2000] | Loss(BCE): 0.2316
# Epoch [136/2000] | Loss(BCE): 0.2387
# Epoch [137/2000] | Loss(BCE): 0.2306
# Epoch [138/2000] | Loss(BCE): 0.2218
# Epoch [139/2000] | Loss(BCE): 0.2182
# Epoch [140/2000] | Loss(BCE): 0.2314
# Epoch [141/2000] | Loss(BCE): 0.2255
# Epoch [142/2000] | Loss(BCE): 0.2225
# Epoch [143/2000] | Loss(BCE): 0.2210
# Epoch [144/2000] | Loss(BCE): 0.2125
# Epoch [145/2000] | Loss(BCE): 0.2147
# Epoch [146/2000] | Loss(BCE): 0.2040
# Epoch [147/2000] | Loss(BCE): 0.2075
# Epoch [148/2000] | Loss(BCE): 0.2079
# Epoch [149/2000] | Loss(BCE): 0.2124
# Epoch [150/2000] | Loss(BCE): 0.2235
# Epoch [151/2000] | Loss(BCE): 0.1989
# Epoch [152/2000] | Loss(BCE): 0.2123
# Epoch [153/2000] | Loss(BCE): 0.2158
# Epoch [154/2000] | Loss(BCE): 0.2024
# Epoch [155/2000] | Loss(BCE): 0.2036
# Epoch [156/2000] | Loss(BCE): 0.2066
# Epoch [157/2000] | Loss(BCE): 0.1957
# Epoch [158/2000] | Loss(BCE): 0.1942
# Epoch [159/2000] | Loss(BCE): 0.2072
# Epoch [160/2000] | Loss(BCE): 0.2117
# Epoch [161/2000] | Loss(BCE): 0.1876
# Epoch [162/2000] | Loss(BCE): 0.1915
# Epoch [163/2000] | Loss(BCE): 0.1953
# Epoch [164/2000] | Loss(BCE): 0.1870
# Epoch [165/2000] | Loss(BCE): 0.1979
# Epoch [166/2000] | Loss(BCE): 0.1915
# Epoch [167/2000] | Loss(BCE): 0.1988
# Epoch [168/2000] | Loss(BCE): 0.1982
# Epoch [169/2000] | Loss(BCE): 0.1879
# Epoch [170/2000] | Loss(BCE): 0.2027
# Epoch [171/2000] | Loss(BCE): 0.1807
# Epoch [172/2000] | Loss(BCE): 0.1926
# Epoch [173/2000] | Loss(BCE): 0.1901
# Epoch [174/2000] | Loss(BCE): 0.1996
# Epoch [175/2000] | Loss(BCE): 0.1929
# Epoch [176/2000] | Loss(BCE): 0.1829
# Epoch [177/2000] | Loss(BCE): 0.1828
# Epoch [178/2000] | Loss(BCE): 0.1864
# Epoch [179/2000] | Loss(BCE): 0.1870
# Epoch [180/2000] | Loss(BCE): 0.1850
# Epoch [181/2000] | Loss(BCE): 0.1784
# Epoch [182/2000] | Loss(BCE): 0.1835
# Epoch [183/2000] | Loss(BCE): 0.1751
# Epoch [184/2000] | Loss(BCE): 0.1814
# Epoch [185/2000] | Loss(BCE): 0.1831
# Epoch [186/2000] | Loss(BCE): 0.1851
# Epoch [187/2000] | Loss(BCE): 0.1718
# Epoch [188/2000] | Loss(BCE): 0.1871
# Epoch [189/2000] | Loss(BCE): 0.1742
# Epoch [190/2000] | Loss(BCE): 0.1707
# Epoch [191/2000] | Loss(BCE): 0.1824
# Epoch [192/2000] | Loss(BCE): 0.1747
# Epoch [193/2000] | Loss(BCE): 0.1753
# Epoch [194/2000] | Loss(BCE): 0.1785
# Epoch [195/2000] | Loss(BCE): 0.1868
# Epoch [196/2000] | Loss(BCE): 0.1603
# Epoch [197/2000] | Loss(BCE): 0.1773
# Epoch [198/2000] | Loss(BCE): 0.1725
# Epoch [199/2000] | Loss(BCE): 0.1573
# Epoch [200/2000] | Loss(BCE): 0.1566
# Epoch [201/2000] | Loss(BCE): 0.1674
# Epoch [202/2000] | Loss(BCE): 0.1850
# Epoch [203/2000] | Loss(BCE): 0.1759
# Epoch [204/2000] | Loss(BCE): 0.1700
# Epoch [205/2000] | Loss(BCE): 0.1748
# Epoch [206/2000] | Loss(BCE): 0.1619
# Epoch [207/2000] | Loss(BCE): 0.1594
# Epoch [208/2000] | Loss(BCE): 0.1614
# Epoch [209/2000] | Loss(BCE): 0.1653
# Epoch [210/2000] | Loss(BCE): 0.1621
# Epoch [211/2000] | Loss(BCE): 0.1642
# Epoch [212/2000] | Loss(BCE): 0.1591
# Epoch [213/2000] | Loss(BCE): 0.1546
# Epoch [214/2000] | Loss(BCE): 0.1651
# Epoch [215/2000] | Loss(BCE): 0.1599
# Epoch [216/2000] | Loss(BCE): 0.1629
# Epoch [217/2000] | Loss(BCE): 0.1616
# Epoch [218/2000] | Loss(BCE): 0.1472
# Epoch [219/2000] | Loss(BCE): 0.1582
# Epoch [220/2000] | Loss(BCE): 0.1684
# Epoch [221/2000] | Loss(BCE): 0.1565
# Epoch [222/2000] | Loss(BCE): 0.1539
# Epoch [223/2000] | Loss(BCE): 0.1661
# Epoch [224/2000] | Loss(BCE): 0.1481
# Epoch [225/2000] | Loss(BCE): 0.1381
# Epoch [226/2000] | Loss(BCE): 0.1585
# Epoch [227/2000] | Loss(BCE): 0.1494
# Epoch [228/2000] | Loss(BCE): 0.1497
# Epoch [229/2000] | Loss(BCE): 0.1736
# Epoch [230/2000] | Loss(BCE): 0.1445
# Epoch [231/2000] | Loss(BCE): 0.1534
# Epoch [232/2000] | Loss(BCE): 0.1563
# Epoch [233/2000] | Loss(BCE): 0.1414
# Epoch [234/2000] | Loss(BCE): 0.1482
# Epoch [235/2000] | Loss(BCE): 0.1442
# Epoch [236/2000] | Loss(BCE): 0.1511
# Epoch [237/2000] | Loss(BCE): 0.1559
# Epoch [238/2000] | Loss(BCE): 0.1463
# Epoch [239/2000] | Loss(BCE): 0.1424
# Epoch [240/2000] | Loss(BCE): 0.1576
# Epoch [241/2000] | Loss(BCE): 0.1323
# Epoch [242/2000] | Loss(BCE): 0.1453
# Epoch [243/2000] | Loss(BCE): 0.1390
# Epoch [244/2000] | Loss(BCE): 0.1595
# Epoch [245/2000] | Loss(BCE): 0.1470
# Epoch [246/2000] | Loss(BCE): 0.1469
# Epoch [247/2000] | Loss(BCE): 0.1467
# Epoch [248/2000] | Loss(BCE): 0.1394
# Epoch [249/2000] | Loss(BCE): 0.1487
# Epoch [250/2000] | Loss(BCE): 0.1422
# Epoch [251/2000] | Loss(BCE): 0.1584
# Epoch [252/2000] | Loss(BCE): 0.1336
# Epoch [253/2000] | Loss(BCE): 0.1359
# Epoch [254/2000] | Loss(BCE): 0.1369
# Epoch [255/2000] | Loss(BCE): 0.1389
# Epoch [256/2000] | Loss(BCE): 0.1368
# Epoch [257/2000] | Loss(BCE): 0.1341
# Epoch [258/2000] | Loss(BCE): 0.1406
# Epoch [259/2000] | Loss(BCE): 0.1489
# Epoch [260/2000] | Loss(BCE): 0.1594
# Epoch [261/2000] | Loss(BCE): 0.1360
# Epoch [262/2000] | Loss(BCE): 0.1304
# Epoch [263/2000] | Loss(BCE): 0.1431
# Epoch [264/2000] | Loss(BCE): 0.1393
# Epoch [265/2000] | Loss(BCE): 0.1455
# Epoch [266/2000] | Loss(BCE): 0.1441
# Epoch [267/2000] | Loss(BCE): 0.1485
# Epoch [268/2000] | Loss(BCE): 0.1307
# Epoch [269/2000] | Loss(BCE): 0.1456
# Epoch [270/2000] | Loss(BCE): 0.1465
# Epoch [271/2000] | Loss(BCE): 0.1239
# Epoch [272/2000] | Loss(BCE): 0.1399
# Epoch [273/2000] | Loss(BCE): 0.1426
# Epoch [274/2000] | Loss(BCE): 0.1338
# Epoch [275/2000] | Loss(BCE): 0.1279
# Epoch [276/2000] | Loss(BCE): 0.1362
# Epoch [277/2000] | Loss(BCE): 0.1343
# Epoch [278/2000] | Loss(BCE): 0.1370
# Epoch [279/2000] | Loss(BCE): 0.1323
# Epoch [280/2000] | Loss(BCE): 0.1310
# Epoch [281/2000] | Loss(BCE): 0.1344
# Epoch [282/2000] | Loss(BCE): 0.1352
# Epoch [283/2000] | Loss(BCE): 0.1450
# Epoch [284/2000] | Loss(BCE): 0.1288
# Epoch [285/2000] | Loss(BCE): 0.1336
# Epoch [286/2000] | Loss(BCE): 0.1331
# Epoch [287/2000] | Loss(BCE): 0.1395
# Epoch [288/2000] | Loss(BCE): 0.1297
# Epoch [289/2000] | Loss(BCE): 0.1280
# Epoch [290/2000] | Loss(BCE): 0.1365
# Epoch [291/2000] | Loss(BCE): 0.1354
# Epoch [292/2000] | Loss(BCE): 0.1258
# Epoch [293/2000] | Loss(BCE): 0.1446
# Epoch [294/2000] | Loss(BCE): 0.1322
# Epoch [295/2000] | Loss(BCE): 0.1276
# Epoch [296/2000] | Loss(BCE): 0.1296
# Epoch [297/2000] | Loss(BCE): 0.1249
# Epoch [298/2000] | Loss(BCE): 0.1345
# Epoch [299/2000] | Loss(BCE): 0.1306
# Epoch [300/2000] | Loss(BCE): 0.1403
# Epoch [301/2000] | Loss(BCE): 0.1311
# Epoch [302/2000] | Loss(BCE): 0.1204
# Epoch [303/2000] | Loss(BCE): 0.1218
# Epoch [304/2000] | Loss(BCE): 0.1293
# Epoch [305/2000] | Loss(BCE): 0.1330
# Epoch [306/2000] | Loss(BCE): 0.1224
# Epoch [307/2000] | Loss(BCE): 0.1317
# Epoch [308/2000] | Loss(BCE): 0.1383
# Epoch [309/2000] | Loss(BCE): 0.1324
# Epoch [310/2000] | Loss(BCE): 0.1349
# Epoch [311/2000] | Loss(BCE): 0.1154
# Epoch [312/2000] | Loss(BCE): 0.1321
# Epoch [313/2000] | Loss(BCE): 0.1297
# Epoch [314/2000] | Loss(BCE): 0.1266
# Epoch [315/2000] | Loss(BCE): 0.1271
# Epoch [316/2000] | Loss(BCE): 0.1288
# Epoch [317/2000] | Loss(BCE): 0.1313
# Epoch [318/2000] | Loss(BCE): 0.1207
# Epoch [319/2000] | Loss(BCE): 0.1219
# Epoch [320/2000] | Loss(BCE): 0.1225
# Epoch [321/2000] | Loss(BCE): 0.1312
# Epoch [322/2000] | Loss(BCE): 0.1294
# Epoch [323/2000] | Loss(BCE): 0.1204
# Epoch [324/2000] | Loss(BCE): 0.1121
# Epoch [325/2000] | Loss(BCE): 0.1216
# Epoch [326/2000] | Loss(BCE): 0.1134
# Epoch [327/2000] | Loss(BCE): 0.1296
# Epoch [328/2000] | Loss(BCE): 0.1251
# Epoch [329/2000] | Loss(BCE): 0.1290
# Epoch [330/2000] | Loss(BCE): 0.1235
# Epoch [331/2000] | Loss(BCE): 0.1194
# Epoch [332/2000] | Loss(BCE): 0.1238
# Epoch [333/2000] | Loss(BCE): 0.1151
# Epoch [334/2000] | Loss(BCE): 0.1304
# Epoch [335/2000] | Loss(BCE): 0.1146
# Epoch [336/2000] | Loss(BCE): 0.1266
# Epoch [337/2000] | Loss(BCE): 0.1237
# Epoch [338/2000] | Loss(BCE): 0.1179
# Epoch [339/2000] | Loss(BCE): 0.1113
# Epoch [340/2000] | Loss(BCE): 0.1146
# Epoch [341/2000] | Loss(BCE): 0.1198
# Epoch [342/2000] | Loss(BCE): 0.1221
# Epoch [343/2000] | Loss(BCE): 0.1175
# Epoch [344/2000] | Loss(BCE): 0.1157
# Epoch [345/2000] | Loss(BCE): 0.1140
# Epoch [346/2000] | Loss(BCE): 0.1115
# Epoch [347/2000] | Loss(BCE): 0.1080
# Epoch [348/2000] | Loss(BCE): 0.1104
# Epoch [349/2000] | Loss(BCE): 0.1192
# Epoch [350/2000] | Loss(BCE): 0.1207
# Epoch [351/2000] | Loss(BCE): 0.1182
# Epoch [352/2000] | Loss(BCE): 0.1107
# Epoch [353/2000] | Loss(BCE): 0.1210
# Epoch [354/2000] | Loss(BCE): 0.1212
# Epoch [355/2000] | Loss(BCE): 0.1119
# Epoch [356/2000] | Loss(BCE): 0.1188
# Epoch [357/2000] | Loss(BCE): 0.1147
# Epoch [358/2000] | Loss(BCE): 0.1091
# Epoch [359/2000] | Loss(BCE): 0.1204
# Epoch [360/2000] | Loss(BCE): 0.1104
# Epoch [361/2000] | Loss(BCE): 0.1196
# Epoch [362/2000] | Loss(BCE): 0.1171
# Epoch [363/2000] | Loss(BCE): 0.1127
# Epoch [364/2000] | Loss(BCE): 0.1221
# Epoch [365/2000] | Loss(BCE): 0.1112
# Epoch [366/2000] | Loss(BCE): 0.1264
# Epoch [367/2000] | Loss(BCE): 0.1031
# Epoch [368/2000] | Loss(BCE): 0.1223
# Epoch [369/2000] | Loss(BCE): 0.1180
# Epoch [370/2000] | Loss(BCE): 0.1177
# Epoch [371/2000] | Loss(BCE): 0.1139
# Epoch [372/2000] | Loss(BCE): 0.1197
# Epoch [373/2000] | Loss(BCE): 0.1132
# Epoch [374/2000] | Loss(BCE): 0.1062
# Epoch [375/2000] | Loss(BCE): 0.1176
# Epoch [376/2000] | Loss(BCE): 0.1098
# Epoch [377/2000] | Loss(BCE): 0.1056
# Epoch [378/2000] | Loss(BCE): 0.1158
# Epoch [379/2000] | Loss(BCE): 0.1120
# Epoch [380/2000] | Loss(BCE): 0.1029
# Epoch [381/2000] | Loss(BCE): 0.1049
# Epoch [382/2000] | Loss(BCE): 0.1180
# Epoch [383/2000] | Loss(BCE): 0.1147
# Epoch [384/2000] | Loss(BCE): 0.1103
# Epoch [385/2000] | Loss(BCE): 0.1116
# Epoch [386/2000] | Loss(BCE): 0.1119
# Epoch [387/2000] | Loss(BCE): 0.1063
# Epoch [388/2000] | Loss(BCE): 0.1081
# Epoch [389/2000] | Loss(BCE): 0.1169
# Epoch [390/2000] | Loss(BCE): 0.1095
# Epoch [391/2000] | Loss(BCE): 0.1108
# Epoch [392/2000] | Loss(BCE): 0.1024
# Epoch [393/2000] | Loss(BCE): 0.0934
# Epoch [394/2000] | Loss(BCE): 0.1082
# Epoch [395/2000] | Loss(BCE): 0.1210
# Epoch [396/2000] | Loss(BCE): 0.1097
# Epoch [397/2000] | Loss(BCE): 0.1126
# Epoch [398/2000] | Loss(BCE): 0.1128
# Epoch [399/2000] | Loss(BCE): 0.1167
# Epoch [400/2000] | Loss(BCE): 0.1133
# Epoch [401/2000] | Loss(BCE): 0.1104
# Epoch [402/2000] | Loss(BCE): 0.1129
# Epoch [403/2000] | Loss(BCE): 0.1044
# Epoch [404/2000] | Loss(BCE): 0.1145
# Epoch [405/2000] | Loss(BCE): 0.1036
# Epoch [406/2000] | Loss(BCE): 0.1147
# Epoch [407/2000] | Loss(BCE): 0.1110
# Epoch [408/2000] | Loss(BCE): 0.1064
# Epoch [409/2000] | Loss(BCE): 0.1083
# Epoch [410/2000] | Loss(BCE): 0.1237
# Epoch [411/2000] | Loss(BCE): 0.1053
# Epoch [412/2000] | Loss(BCE): 0.1232
# Epoch [413/2000] | Loss(BCE): 0.1139
# Epoch [414/2000] | Loss(BCE): 0.1106
# Epoch [415/2000] | Loss(BCE): 0.0942
# Epoch [416/2000] | Loss(BCE): 0.1107
# Epoch [417/2000] | Loss(BCE): 0.1090
# Epoch [418/2000] | Loss(BCE): 0.0890
# Epoch [419/2000] | Loss(BCE): 0.1069
# Epoch [420/2000] | Loss(BCE): 0.1056
# Epoch [421/2000] | Loss(BCE): 0.1091
# Epoch [422/2000] | Loss(BCE): 0.1038
# Epoch [423/2000] | Loss(BCE): 0.0998
# Epoch [424/2000] | Loss(BCE): 0.1094
# Epoch [425/2000] | Loss(BCE): 0.1022
# Epoch [426/2000] | Loss(BCE): 0.0988
# Epoch [427/2000] | Loss(BCE): 0.1054
# Epoch [428/2000] | Loss(BCE): 0.1114
# Epoch [429/2000] | Loss(BCE): 0.1137
# Epoch [430/2000] | Loss(BCE): 0.0958
# Epoch [431/2000] | Loss(BCE): 0.1046
# Epoch [432/2000] | Loss(BCE): 0.1041
# Epoch [433/2000] | Loss(BCE): 0.1055
# Epoch [434/2000] | Loss(BCE): 0.1026
# Epoch [435/2000] | Loss(BCE): 0.0999
# Epoch [436/2000] | Loss(BCE): 0.0938
# Epoch [437/2000] | Loss(BCE): 0.1016
# Epoch [438/2000] | Loss(BCE): 0.0866
# Epoch [439/2000] | Loss(BCE): 0.1056
# Epoch [440/2000] | Loss(BCE): 0.1046
# Epoch [441/2000] | Loss(BCE): 0.0946
# Epoch [442/2000] | Loss(BCE): 0.0997
# Epoch [443/2000] | Loss(BCE): 0.0922
# Epoch [444/2000] | Loss(BCE): 0.0981
# Epoch [445/2000] | Loss(BCE): 0.1030
# Epoch [446/2000] | Loss(BCE): 0.0963
# Epoch [447/2000] | Loss(BCE): 0.0934
# Epoch [448/2000] | Loss(BCE): 0.1031
# Epoch [449/2000] | Loss(BCE): 0.0994
# Epoch [450/2000] | Loss(BCE): 0.1004
# Epoch [451/2000] | Loss(BCE): 0.0944
# Epoch [452/2000] | Loss(BCE): 0.1102
# Epoch [453/2000] | Loss(BCE): 0.0930
# Epoch [454/2000] | Loss(BCE): 0.0891
# Epoch [455/2000] | Loss(BCE): 0.1040
# Epoch [456/2000] | Loss(BCE): 0.1116
# Epoch [457/2000] | Loss(BCE): 0.1016
# Epoch [458/2000] | Loss(BCE): 0.1125
# Epoch [459/2000] | Loss(BCE): 0.1057
# Epoch [460/2000] | Loss(BCE): 0.0912
# Epoch [461/2000] | Loss(BCE): 0.0919
# Epoch [462/2000] | Loss(BCE): 0.1147
# Epoch [463/2000] | Loss(BCE): 0.1024
# Epoch [464/2000] | Loss(BCE): 0.0964
# Epoch [465/2000] | Loss(BCE): 0.0931
# Epoch [466/2000] | Loss(BCE): 0.0943
# Epoch [467/2000] | Loss(BCE): 0.1027
# Epoch [468/2000] | Loss(BCE): 0.1006
# Epoch [469/2000] | Loss(BCE): 0.0986
# Epoch [470/2000] | Loss(BCE): 0.0940
# Epoch [471/2000] | Loss(BCE): 0.0945
# Epoch [472/2000] | Loss(BCE): 0.1003
# Epoch [473/2000] | Loss(BCE): 0.0985
# Epoch [474/2000] | Loss(BCE): 0.1055
# Epoch [475/2000] | Loss(BCE): 0.1043
# Epoch [476/2000] | Loss(BCE): 0.1024
# Epoch [477/2000] | Loss(BCE): 0.1021
# Epoch [478/2000] | Loss(BCE): 0.1033
# Epoch [479/2000] | Loss(BCE): 0.0947
# Epoch [480/2000] | Loss(BCE): 0.0959
# Epoch [481/2000] | Loss(BCE): 0.0922
# Epoch [482/2000] | Loss(BCE): 0.0973
# Epoch [483/2000] | Loss(BCE): 0.0952
# Epoch [484/2000] | Loss(BCE): 0.0915
# Epoch [485/2000] | Loss(BCE): 0.0870
# Epoch [486/2000] | Loss(BCE): 0.0953
# Epoch [487/2000] | Loss(BCE): 0.0997
# Epoch [488/2000] | Loss(BCE): 0.0975
# Epoch [489/2000] | Loss(BCE): 0.1012
# Epoch [490/2000] | Loss(BCE): 0.1002
# Epoch [491/2000] | Loss(BCE): 0.0951
# Epoch [492/2000] | Loss(BCE): 0.0933
# Epoch [493/2000] | Loss(BCE): 0.0940
# Epoch [494/2000] | Loss(BCE): 0.0922
# Epoch [495/2000] | Loss(BCE): 0.1037
# Epoch [496/2000] | Loss(BCE): 0.0944
# Epoch [497/2000] | Loss(BCE): 0.0896
# Epoch [498/2000] | Loss(BCE): 0.0923
# Epoch [499/2000] | Loss(BCE): 0.0919
# Epoch [500/2000] | Loss(BCE): 0.0961
# Epoch [501/2000] | Loss(BCE): 0.0928
# Epoch [502/2000] | Loss(BCE): 0.0978
# Epoch [503/2000] | Loss(BCE): 0.0875
# Epoch [504/2000] | Loss(BCE): 0.1102
# Epoch [505/2000] | Loss(BCE): 0.0981
# Epoch [506/2000] | Loss(BCE): 0.0913
# Epoch [507/2000] | Loss(BCE): 0.1042
# Epoch [508/2000] | Loss(BCE): 0.0931
# Epoch [509/2000] | Loss(BCE): 0.0950
# Epoch [510/2000] | Loss(BCE): 0.0829
# Epoch [511/2000] | Loss(BCE): 0.0977
# Epoch [512/2000] | Loss(BCE): 0.0993
# Epoch [513/2000] | Loss(BCE): 0.0914
# Epoch [514/2000] | Loss(BCE): 0.0979
# Epoch [515/2000] | Loss(BCE): 0.0842
# Epoch [516/2000] | Loss(BCE): 0.0886
# Epoch [517/2000] | Loss(BCE): 0.0871
# Epoch [518/2000] | Loss(BCE): 0.0957
# Epoch [519/2000] | Loss(BCE): 0.1041
# Epoch [520/2000] | Loss(BCE): 0.0822
# Epoch [521/2000] | Loss(BCE): 0.0963
# Epoch [522/2000] | Loss(BCE): 0.0930
# Epoch [523/2000] | Loss(BCE): 0.0970
# Epoch [524/2000] | Loss(BCE): 0.0965
# Epoch [525/2000] | Loss(BCE): 0.0861
# Epoch [526/2000] | Loss(BCE): 0.0941
# Epoch [527/2000] | Loss(BCE): 0.0895
# Epoch [528/2000] | Loss(BCE): 0.0850
# Epoch [529/2000] | Loss(BCE): 0.0919
# Epoch [530/2000] | Loss(BCE): 0.0984
# Epoch [531/2000] | Loss(BCE): 0.0996
# Epoch [532/2000] | Loss(BCE): 0.1002
# Epoch [533/2000] | Loss(BCE): 0.0939
# Epoch [534/2000] | Loss(BCE): 0.0964
# Epoch [535/2000] | Loss(BCE): 0.0862
# Epoch [536/2000] | Loss(BCE): 0.1022
# Epoch [537/2000] | Loss(BCE): 0.0895
# Epoch [538/2000] | Loss(BCE): 0.0937
# Epoch [539/2000] | Loss(BCE): 0.0973
# Epoch [540/2000] | Loss(BCE): 0.0949
# Epoch [541/2000] | Loss(BCE): 0.0858
# Epoch [542/2000] | Loss(BCE): 0.0969
# Epoch [543/2000] | Loss(BCE): 0.0948
# Epoch [544/2000] | Loss(BCE): 0.0995
# Epoch [545/2000] | Loss(BCE): 0.0851
# Epoch [546/2000] | Loss(BCE): 0.0973
# Epoch [547/2000] | Loss(BCE): 0.0982
# Epoch [548/2000] | Loss(BCE): 0.0904
# Epoch [549/2000] | Loss(BCE): 0.1019
# Epoch [550/2000] | Loss(BCE): 0.0946
# Epoch [551/2000] | Loss(BCE): 0.0849
# Epoch [552/2000] | Loss(BCE): 0.0879
# Epoch [553/2000] | Loss(BCE): 0.0918
# Epoch [554/2000] | Loss(BCE): 0.0964
# Epoch [555/2000] | Loss(BCE): 0.0902
# Epoch [556/2000] | Loss(BCE): 0.0945
# Epoch [557/2000] | Loss(BCE): 0.0935
# Epoch [558/2000] | Loss(BCE): 0.0833
# Epoch [559/2000] | Loss(BCE): 0.0899
# Epoch [560/2000] | Loss(BCE): 0.0824
# Epoch [561/2000] | Loss(BCE): 0.0974
# Epoch [562/2000] | Loss(BCE): 0.0716
# Epoch [563/2000] | Loss(BCE): 0.0871
# Epoch [564/2000] | Loss(BCE): 0.0814
# Epoch [565/2000] | Loss(BCE): 0.0825
# Epoch [566/2000] | Loss(BCE): 0.0845
# Epoch [567/2000] | Loss(BCE): 0.0830
# Epoch [568/2000] | Loss(BCE): 0.1017
# Epoch [569/2000] | Loss(BCE): 0.0874
# Epoch [570/2000] | Loss(BCE): 0.0799
# Epoch [571/2000] | Loss(BCE): 0.0711
# Epoch [572/2000] | Loss(BCE): 0.1015
# Epoch [573/2000] | Loss(BCE): 0.0878
# Epoch [574/2000] | Loss(BCE): 0.0934
# Epoch [575/2000] | Loss(BCE): 0.0821
# Epoch [576/2000] | Loss(BCE): 0.0791
# Epoch [577/2000] | Loss(BCE): 0.0852
# Epoch [578/2000] | Loss(BCE): 0.0827
# Epoch [579/2000] | Loss(BCE): 0.0927
# Epoch [580/2000] | Loss(BCE): 0.0903
# Epoch [581/2000] | Loss(BCE): 0.0942
# Epoch [582/2000] | Loss(BCE): 0.0926
# Epoch [583/2000] | Loss(BCE): 0.0824
# Epoch [584/2000] | Loss(BCE): 0.0891
# Epoch [585/2000] | Loss(BCE): 0.0817
# Epoch [586/2000] | Loss(BCE): 0.0856
# Epoch [587/2000] | Loss(BCE): 0.0912
# Epoch [588/2000] | Loss(BCE): 0.0967
# Epoch [589/2000] | Loss(BCE): 0.0883
# Epoch [590/2000] | Loss(BCE): 0.0855
# Epoch [591/2000] | Loss(BCE): 0.0881
# Epoch [592/2000] | Loss(BCE): 0.0862
# Epoch [593/2000] | Loss(BCE): 0.0843
# Epoch [594/2000] | Loss(BCE): 0.0836
# Epoch [595/2000] | Loss(BCE): 0.0779
# Epoch [596/2000] | Loss(BCE): 0.0947
# Epoch [597/2000] | Loss(BCE): 0.0900
# Epoch [598/2000] | Loss(BCE): 0.0866
# Epoch [599/2000] | Loss(BCE): 0.0793
# Epoch [600/2000] | Loss(BCE): 0.0845
# Epoch [601/2000] | Loss(BCE): 0.0895
# Epoch [602/2000] | Loss(BCE): 0.0849
# Epoch [603/2000] | Loss(BCE): 0.0880
# Epoch [604/2000] | Loss(BCE): 0.0881
# Epoch [605/2000] | Loss(BCE): 0.0885
# Epoch [606/2000] | Loss(BCE): 0.0834
# Epoch [607/2000] | Loss(BCE): 0.0862
# Epoch [608/2000] | Loss(BCE): 0.0825
# Epoch [609/2000] | Loss(BCE): 0.0944
# Epoch [610/2000] | Loss(BCE): 0.0787
# Epoch [611/2000] | Loss(BCE): 0.0770
# Epoch [612/2000] | Loss(BCE): 0.0883
# Epoch [613/2000] | Loss(BCE): 0.0954
# Epoch [614/2000] | Loss(BCE): 0.0845
# Epoch [615/2000] | Loss(BCE): 0.0827
# Epoch [616/2000] | Loss(BCE): 0.0889
# Epoch [617/2000] | Loss(BCE): 0.0876
# Epoch [618/2000] | Loss(BCE): 0.0754
# Epoch [619/2000] | Loss(BCE): 0.0815
# Epoch [620/2000] | Loss(BCE): 0.0822
# Epoch [621/2000] | Loss(BCE): 0.0741
# Epoch [622/2000] | Loss(BCE): 0.0840
# Epoch [623/2000] | Loss(BCE): 0.0944
# Epoch [624/2000] | Loss(BCE): 0.0847
# Epoch [625/2000] | Loss(BCE): 0.0810
# Epoch [626/2000] | Loss(BCE): 0.0867
# Epoch [627/2000] | Loss(BCE): 0.0763
# Epoch [628/2000] | Loss(BCE): 0.0866
# Epoch [629/2000] | Loss(BCE): 0.0798
# Epoch [630/2000] | Loss(BCE): 0.0784
# Epoch [631/2000] | Loss(BCE): 0.0887
# Epoch [632/2000] | Loss(BCE): 0.0900
# Epoch [633/2000] | Loss(BCE): 0.0953
# Epoch [634/2000] | Loss(BCE): 0.0834
# Epoch [635/2000] | Loss(BCE): 0.0947
# Epoch [636/2000] | Loss(BCE): 0.0948
# Epoch [637/2000] | Loss(BCE): 0.0817
# Epoch [638/2000] | Loss(BCE): 0.0883
# Epoch [639/2000] | Loss(BCE): 0.0979
# Epoch [640/2000] | Loss(BCE): 0.0849
# Epoch [641/2000] | Loss(BCE): 0.0862
# Epoch [642/2000] | Loss(BCE): 0.0962
# Epoch [643/2000] | Loss(BCE): 0.0776
# Epoch [644/2000] | Loss(BCE): 0.0836
# Epoch [645/2000] | Loss(BCE): 0.0824
# Epoch [646/2000] | Loss(BCE): 0.0814
# Epoch [647/2000] | Loss(BCE): 0.0874
# Epoch [648/2000] | Loss(BCE): 0.0770
# Epoch [649/2000] | Loss(BCE): 0.0806
# Epoch [650/2000] | Loss(BCE): 0.0866
# Epoch [651/2000] | Loss(BCE): 0.0827
# Epoch [652/2000] | Loss(BCE): 0.0931
# Epoch [653/2000] | Loss(BCE): 0.0782
# Epoch [654/2000] | Loss(BCE): 0.0829
# Epoch [655/2000] | Loss(BCE): 0.0895
# Epoch [656/2000] | Loss(BCE): 0.0765
# Epoch [657/2000] | Loss(BCE): 0.0820
# Epoch [658/2000] | Loss(BCE): 0.0794
# Epoch [659/2000] | Loss(BCE): 0.0883
# Epoch [660/2000] | Loss(BCE): 0.0901
# Epoch [661/2000] | Loss(BCE): 0.0899
# Epoch [662/2000] | Loss(BCE): 0.0901
# Epoch [663/2000] | Loss(BCE): 0.0825
# Epoch [664/2000] | Loss(BCE): 0.0778
# Epoch [665/2000] | Loss(BCE): 0.0852
# Epoch [666/2000] | Loss(BCE): 0.0897
# Epoch [667/2000] | Loss(BCE): 0.0749
# Epoch [668/2000] | Loss(BCE): 0.0739
# Epoch [669/2000] | Loss(BCE): 0.0855
# Epoch [670/2000] | Loss(BCE): 0.0729
# Epoch [671/2000] | Loss(BCE): 0.0844
# Epoch [672/2000] | Loss(BCE): 0.0822
# Epoch [673/2000] | Loss(BCE): 0.0872
# Epoch [674/2000] | Loss(BCE): 0.0826
# Epoch [675/2000] | Loss(BCE): 0.0838
# Epoch [676/2000] | Loss(BCE): 0.0778
# Epoch [677/2000] | Loss(BCE): 0.0782
# Epoch [678/2000] | Loss(BCE): 0.0719
# Epoch [679/2000] | Loss(BCE): 0.0900
# Epoch [680/2000] | Loss(BCE): 0.0792
# Epoch [681/2000] | Loss(BCE): 0.0782
# Epoch [682/2000] | Loss(BCE): 0.0909
# Epoch [683/2000] | Loss(BCE): 0.0871
# Epoch [684/2000] | Loss(BCE): 0.0837
# Epoch [685/2000] | Loss(BCE): 0.0993
# Epoch [686/2000] | Loss(BCE): 0.0873
# Epoch [687/2000] | Loss(BCE): 0.0808
# Epoch [688/2000] | Loss(BCE): 0.0823
# Epoch [689/2000] | Loss(BCE): 0.0917
# Epoch [690/2000] | Loss(BCE): 0.0828
# Epoch [691/2000] | Loss(BCE): 0.0870
# Epoch [692/2000] | Loss(BCE): 0.0857
# Epoch [693/2000] | Loss(BCE): 0.0932
# Epoch [694/2000] | Loss(BCE): 0.0855
# Epoch [695/2000] | Loss(BCE): 0.0921
# Epoch [696/2000] | Loss(BCE): 0.0906
# Epoch [697/2000] | Loss(BCE): 0.0866
# Epoch [698/2000] | Loss(BCE): 0.0876
# Epoch [699/2000] | Loss(BCE): 0.0846
# Epoch [700/2000] | Loss(BCE): 0.0806
# Epoch [701/2000] | Loss(BCE): 0.0794
# Epoch [702/2000] | Loss(BCE): 0.0816
# Epoch [703/2000] | Loss(BCE): 0.0881
# Epoch [704/2000] | Loss(BCE): 0.0844
# Epoch [705/2000] | Loss(BCE): 0.0838
# Epoch [706/2000] | Loss(BCE): 0.0861
# Epoch [707/2000] | Loss(BCE): 0.0746
# Epoch [708/2000] | Loss(BCE): 0.0767
# Epoch [709/2000] | Loss(BCE): 0.0836
# Epoch [710/2000] | Loss(BCE): 0.0818
# Epoch [711/2000] | Loss(BCE): 0.0862
# Epoch [712/2000] | Loss(BCE): 0.0765
# Epoch [713/2000] | Loss(BCE): 0.0780
# Epoch [714/2000] | Loss(BCE): 0.0817
# Epoch [715/2000] | Loss(BCE): 0.0841
# Epoch [716/2000] | Loss(BCE): 0.0826
# Epoch [717/2000] | Loss(BCE): 0.0775
# Epoch [718/2000] | Loss(BCE): 0.0706
# Epoch [719/2000] | Loss(BCE): 0.0808
# Epoch [720/2000] | Loss(BCE): 0.0780
# Epoch [721/2000] | Loss(BCE): 0.0769
# Epoch [722/2000] | Loss(BCE): 0.0803
# Epoch [723/2000] | Loss(BCE): 0.0749
# Epoch [724/2000] | Loss(BCE): 0.0869
# Epoch [725/2000] | Loss(BCE): 0.0820
# Epoch [726/2000] | Loss(BCE): 0.0820
# Epoch [727/2000] | Loss(BCE): 0.0793
# Epoch [728/2000] | Loss(BCE): 0.0763
# Epoch [729/2000] | Loss(BCE): 0.0758
# Epoch [730/2000] | Loss(BCE): 0.0780
# Epoch [731/2000] | Loss(BCE): 0.0782
# Epoch [732/2000] | Loss(BCE): 0.0795
# Epoch [733/2000] | Loss(BCE): 0.0776
# Epoch [734/2000] | Loss(BCE): 0.0758
# Epoch [735/2000] | Loss(BCE): 0.0757
# Epoch [736/2000] | Loss(BCE): 0.0819
# Epoch [737/2000] | Loss(BCE): 0.0786
# Epoch [738/2000] | Loss(BCE): 0.0745
# Epoch [739/2000] | Loss(BCE): 0.0824
# Epoch [740/2000] | Loss(BCE): 0.0744
# Epoch [741/2000] | Loss(BCE): 0.0711
# Epoch [742/2000] | Loss(BCE): 0.0737
# Epoch [743/2000] | Loss(BCE): 0.0824
# Epoch [744/2000] | Loss(BCE): 0.0878
# Epoch [745/2000] | Loss(BCE): 0.0827
# Epoch [746/2000] | Loss(BCE): 0.0873
# Epoch [747/2000] | Loss(BCE): 0.0910
# Epoch [748/2000] | Loss(BCE): 0.0700
# Epoch [749/2000] | Loss(BCE): 0.0744
# Epoch [750/2000] | Loss(BCE): 0.0948
# Epoch [751/2000] | Loss(BCE): 0.0715
# Epoch [752/2000] | Loss(BCE): 0.0800
# Epoch [753/2000] | Loss(BCE): 0.0776
# Epoch [754/2000] | Loss(BCE): 0.0857
# Epoch [755/2000] | Loss(BCE): 0.0797
# Epoch [756/2000] | Loss(BCE): 0.0760
# Epoch [757/2000] | Loss(BCE): 0.0864
# Epoch [758/2000] | Loss(BCE): 0.0881
# Epoch [759/2000] | Loss(BCE): 0.0775
# Epoch [760/2000] | Loss(BCE): 0.0789
# Epoch [761/2000] | Loss(BCE): 0.0705
# Epoch [762/2000] | Loss(BCE): 0.0922
# Epoch [763/2000] | Loss(BCE): 0.0774
# Epoch [764/2000] | Loss(BCE): 0.0684
# Epoch [765/2000] | Loss(BCE): 0.0827
# Epoch [766/2000] | Loss(BCE): 0.0723
# Epoch [767/2000] | Loss(BCE): 0.0735
# Epoch [768/2000] | Loss(BCE): 0.0687
# Epoch [769/2000] | Loss(BCE): 0.0791
# Epoch [770/2000] | Loss(BCE): 0.0783
# Epoch [771/2000] | Loss(BCE): 0.0817
# Epoch [772/2000] | Loss(BCE): 0.0798
# Epoch [773/2000] | Loss(BCE): 0.0887
# Epoch [774/2000] | Loss(BCE): 0.0787
# Epoch [775/2000] | Loss(BCE): 0.0791
# Epoch [776/2000] | Loss(BCE): 0.0767
# Epoch [777/2000] | Loss(BCE): 0.0770
# Epoch [778/2000] | Loss(BCE): 0.0838
# Epoch [779/2000] | Loss(BCE): 0.0721
# Epoch [780/2000] | Loss(BCE): 0.0763
# Epoch [781/2000] | Loss(BCE): 0.0838
# Epoch [782/2000] | Loss(BCE): 0.0837
# Epoch [783/2000] | Loss(BCE): 0.0745
# Epoch [784/2000] | Loss(BCE): 0.0779
# Epoch [785/2000] | Loss(BCE): 0.0862
# Epoch [786/2000] | Loss(BCE): 0.0784
# Epoch [787/2000] | Loss(BCE): 0.0826
# Epoch [788/2000] | Loss(BCE): 0.0761
# Epoch [789/2000] | Loss(BCE): 0.0727
# Epoch [790/2000] | Loss(BCE): 0.0852
# Epoch [791/2000] | Loss(BCE): 0.0729
# Epoch [792/2000] | Loss(BCE): 0.0782
# Epoch [793/2000] | Loss(BCE): 0.0768
# Epoch [794/2000] | Loss(BCE): 0.0743
# Epoch [795/2000] | Loss(BCE): 0.0870
# Epoch [796/2000] | Loss(BCE): 0.0760
# Epoch [797/2000] | Loss(BCE): 0.0815
# Epoch [798/2000] | Loss(BCE): 0.0750
# Epoch [799/2000] | Loss(BCE): 0.0904
# Epoch [800/2000] | Loss(BCE): 0.0769
# Epoch [801/2000] | Loss(BCE): 0.0654
# Epoch [802/2000] | Loss(BCE): 0.0846
# Epoch [803/2000] | Loss(BCE): 0.0826
# Epoch [804/2000] | Loss(BCE): 0.0722
# Epoch [805/2000] | Loss(BCE): 0.0668
# Epoch [806/2000] | Loss(BCE): 0.0643
# Epoch [807/2000] | Loss(BCE): 0.0763
# Epoch [808/2000] | Loss(BCE): 0.0710
# Epoch [809/2000] | Loss(BCE): 0.0718
# Epoch [810/2000] | Loss(BCE): 0.0831
# Epoch [811/2000] | Loss(BCE): 0.0747
# Epoch [812/2000] | Loss(BCE): 0.0758
# Epoch [813/2000] | Loss(BCE): 0.0767
# Epoch [814/2000] | Loss(BCE): 0.0647
# Epoch [815/2000] | Loss(BCE): 0.0783
# Epoch [816/2000] | Loss(BCE): 0.0705
# Epoch [817/2000] | Loss(BCE): 0.0868
# Epoch [818/2000] | Loss(BCE): 0.0799
# Epoch [819/2000] | Loss(BCE): 0.0730
# Epoch [820/2000] | Loss(BCE): 0.0709
# Epoch [821/2000] | Loss(BCE): 0.0862
# Epoch [822/2000] | Loss(BCE): 0.0725
# Epoch [823/2000] | Loss(BCE): 0.0774
# Epoch [824/2000] | Loss(BCE): 0.0899
# Epoch [825/2000] | Loss(BCE): 0.0754
# Epoch [826/2000] | Loss(BCE): 0.0692
# Epoch [827/2000] | Loss(BCE): 0.0718
# Epoch [828/2000] | Loss(BCE): 0.0778
# Epoch [829/2000] | Loss(BCE): 0.0761
# Epoch [830/2000] | Loss(BCE): 0.0767
# Epoch [831/2000] | Loss(BCE): 0.0762
# Epoch [832/2000] | Loss(BCE): 0.0783
# Epoch [833/2000] | Loss(BCE): 0.0783
# Epoch [834/2000] | Loss(BCE): 0.0776
# Epoch [835/2000] | Loss(BCE): 0.0759
# Epoch [836/2000] | Loss(BCE): 0.0756
# Epoch [837/2000] | Loss(BCE): 0.0749
# Epoch [838/2000] | Loss(BCE): 0.0822
# Epoch [839/2000] | Loss(BCE): 0.0716
# Epoch [840/2000] | Loss(BCE): 0.0746
# Epoch [841/2000] | Loss(BCE): 0.0784
# Epoch [842/2000] | Loss(BCE): 0.0766
# Epoch [843/2000] | Loss(BCE): 0.0864
# Epoch [844/2000] | Loss(BCE): 0.0719
# Epoch [845/2000] | Loss(BCE): 0.0722
# Epoch [846/2000] | Loss(BCE): 0.0794
# Epoch [847/2000] | Loss(BCE): 0.0695
# Epoch [848/2000] | Loss(BCE): 0.0839
# Epoch [849/2000] | Loss(BCE): 0.0839
# Epoch [850/2000] | Loss(BCE): 0.0736
# Epoch [851/2000] | Loss(BCE): 0.0741
# Epoch [852/2000] | Loss(BCE): 0.0782
# Epoch [853/2000] | Loss(BCE): 0.0718
# Epoch [854/2000] | Loss(BCE): 0.0805
# Epoch [855/2000] | Loss(BCE): 0.0775
# Epoch [856/2000] | Loss(BCE): 0.0750
# Epoch [857/2000] | Loss(BCE): 0.0677
# Epoch [858/2000] | Loss(BCE): 0.0767
# Epoch [859/2000] | Loss(BCE): 0.0711
# Epoch [860/2000] | Loss(BCE): 0.0851
# Epoch [861/2000] | Loss(BCE): 0.0823
# Epoch [862/2000] | Loss(BCE): 0.0723
# Epoch [863/2000] | Loss(BCE): 0.0737
# Epoch [864/2000] | Loss(BCE): 0.0766
# Epoch [865/2000] | Loss(BCE): 0.0793
# Epoch [866/2000] | Loss(BCE): 0.0671
# Epoch [867/2000] | Loss(BCE): 0.0844
# Epoch [868/2000] | Loss(BCE): 0.0669
# Epoch [869/2000] | Loss(BCE): 0.0653
# Epoch [870/2000] | Loss(BCE): 0.0684
# Epoch [871/2000] | Loss(BCE): 0.0808
# Epoch [872/2000] | Loss(BCE): 0.0770
# Epoch [873/2000] | Loss(BCE): 0.0721
# Epoch [874/2000] | Loss(BCE): 0.0796
# Epoch [875/2000] | Loss(BCE): 0.0782
# Epoch [876/2000] | Loss(BCE): 0.0749
# Epoch [877/2000] | Loss(BCE): 0.0642
# Epoch [878/2000] | Loss(BCE): 0.0732
# Epoch [879/2000] | Loss(BCE): 0.0922
# Epoch [880/2000] | Loss(BCE): 0.0734
# Epoch [881/2000] | Loss(BCE): 0.0630
# Epoch [882/2000] | Loss(BCE): 0.0708
# Epoch [883/2000] | Loss(BCE): 0.0753
# Epoch [884/2000] | Loss(BCE): 0.0772
# Epoch [885/2000] | Loss(BCE): 0.0706
# Epoch [886/2000] | Loss(BCE): 0.0674
# Epoch [887/2000] | Loss(BCE): 0.0770
# Epoch [888/2000] | Loss(BCE): 0.0864
# Epoch [889/2000] | Loss(BCE): 0.0642
# Epoch [890/2000] | Loss(BCE): 0.0800
# Epoch [891/2000] | Loss(BCE): 0.0693
# Epoch [892/2000] | Loss(BCE): 0.0718
# Epoch [893/2000] | Loss(BCE): 0.0709
# Epoch [894/2000] | Loss(BCE): 0.0743
# Epoch [895/2000] | Loss(BCE): 0.0707
# Epoch [896/2000] | Loss(BCE): 0.0771
# Epoch [897/2000] | Loss(BCE): 0.0736
# Epoch [898/2000] | Loss(BCE): 0.0741
# Epoch [899/2000] | Loss(BCE): 0.0669
# Epoch [900/2000] | Loss(BCE): 0.0799
# Epoch [901/2000] | Loss(BCE): 0.0835
# Epoch [902/2000] | Loss(BCE): 0.0710
# Epoch [903/2000] | Loss(BCE): 0.0734
# Epoch [904/2000] | Loss(BCE): 0.0719
# Epoch [905/2000] | Loss(BCE): 0.0788
# Epoch [906/2000] | Loss(BCE): 0.0738
# Epoch [907/2000] | Loss(BCE): 0.0683
# Epoch [908/2000] | Loss(BCE): 0.0724
# Epoch [909/2000] | Loss(BCE): 0.0647
# Epoch [910/2000] | Loss(BCE): 0.0747
# Epoch [911/2000] | Loss(BCE): 0.0750
# Epoch [912/2000] | Loss(BCE): 0.0668
# Epoch [913/2000] | Loss(BCE): 0.0768
# Epoch [914/2000] | Loss(BCE): 0.0687
# Epoch [915/2000] | Loss(BCE): 0.0712
# Epoch [916/2000] | Loss(BCE): 0.0736
# Epoch [917/2000] | Loss(BCE): 0.0676
# Epoch [918/2000] | Loss(BCE): 0.0619
# Epoch [919/2000] | Loss(BCE): 0.0721
# Epoch [920/2000] | Loss(BCE): 0.0639
# Epoch [921/2000] | Loss(BCE): 0.0636
# Epoch [922/2000] | Loss(BCE): 0.0857
# Epoch [923/2000] | Loss(BCE): 0.0730
# Epoch [924/2000] | Loss(BCE): 0.0703
# Epoch [925/2000] | Loss(BCE): 0.0738
# Epoch [926/2000] | Loss(BCE): 0.0764
# Epoch [927/2000] | Loss(BCE): 0.0709
# Epoch [928/2000] | Loss(BCE): 0.0761
# Epoch [929/2000] | Loss(BCE): 0.0707
# Epoch [930/2000] | Loss(BCE): 0.0688
# Epoch [931/2000] | Loss(BCE): 0.0756
# Epoch [932/2000] | Loss(BCE): 0.0743
# Epoch [933/2000] | Loss(BCE): 0.0729
# Epoch [934/2000] | Loss(BCE): 0.0701
# Epoch [935/2000] | Loss(BCE): 0.0683
# Epoch [936/2000] | Loss(BCE): 0.0649
# Epoch [937/2000] | Loss(BCE): 0.0807
# Epoch [938/2000] | Loss(BCE): 0.0745
# Epoch [939/2000] | Loss(BCE): 0.0820
# Epoch [940/2000] | Loss(BCE): 0.0670
# Epoch [941/2000] | Loss(BCE): 0.0836
# Epoch [942/2000] | Loss(BCE): 0.0736
# Epoch [943/2000] | Loss(BCE): 0.0680
# Epoch [944/2000] | Loss(BCE): 0.0730
# Epoch [945/2000] | Loss(BCE): 0.0616
# Epoch [946/2000] | Loss(BCE): 0.0775
# Epoch [947/2000] | Loss(BCE): 0.0672
# Epoch [948/2000] | Loss(BCE): 0.0826
# Epoch [949/2000] | Loss(BCE): 0.0729
# Epoch [950/2000] | Loss(BCE): 0.0647
# Epoch [951/2000] | Loss(BCE): 0.0759
# Epoch [952/2000] | Loss(BCE): 0.0752
# Epoch [953/2000] | Loss(BCE): 0.0624
# Epoch [954/2000] | Loss(BCE): 0.0742
# Epoch [955/2000] | Loss(BCE): 0.0721
# Epoch [956/2000] | Loss(BCE): 0.0682
# Epoch [957/2000] | Loss(BCE): 0.0556
# Epoch [958/2000] | Loss(BCE): 0.0639
# Epoch [959/2000] | Loss(BCE): 0.0670
# Epoch [960/2000] | Loss(BCE): 0.0820
# Epoch [961/2000] | Loss(BCE): 0.0693
# Epoch [962/2000] | Loss(BCE): 0.0596
# Epoch [963/2000] | Loss(BCE): 0.0736
# Epoch [964/2000] | Loss(BCE): 0.0708
# Epoch [965/2000] | Loss(BCE): 0.0590
# Epoch [966/2000] | Loss(BCE): 0.0642
# Epoch [967/2000] | Loss(BCE): 0.0783
# Epoch [968/2000] | Loss(BCE): 0.0689
# Epoch [969/2000] | Loss(BCE): 0.0650
# Epoch [970/2000] | Loss(BCE): 0.0598
# Epoch [971/2000] | Loss(BCE): 0.0670
# Epoch [972/2000] | Loss(BCE): 0.0600
# Epoch [973/2000] | Loss(BCE): 0.0739
# Epoch [974/2000] | Loss(BCE): 0.0644
# Epoch [975/2000] | Loss(BCE): 0.0665
# Epoch [976/2000] | Loss(BCE): 0.0703
# Epoch [977/2000] | Loss(BCE): 0.0700
# Epoch [978/2000] | Loss(BCE): 0.0691
# Epoch [979/2000] | Loss(BCE): 0.0732
# Epoch [980/2000] | Loss(BCE): 0.0650
# Epoch [981/2000] | Loss(BCE): 0.0780
# Epoch [982/2000] | Loss(BCE): 0.0769
# Epoch [983/2000] | Loss(BCE): 0.0625
# Epoch [984/2000] | Loss(BCE): 0.0673
# Epoch [985/2000] | Loss(BCE): 0.0596
# Epoch [986/2000] | Loss(BCE): 0.0631
# Epoch [987/2000] | Loss(BCE): 0.0730
# Epoch [988/2000] | Loss(BCE): 0.0810
# Epoch [989/2000] | Loss(BCE): 0.0719
# Epoch [990/2000] | Loss(BCE): 0.0712
# Epoch [991/2000] | Loss(BCE): 0.0687
# Epoch [992/2000] | Loss(BCE): 0.0751
# Epoch [993/2000] | Loss(BCE): 0.0799
# Epoch [994/2000] | Loss(BCE): 0.0675
# Epoch [995/2000] | Loss(BCE): 0.0643
# Epoch [996/2000] | Loss(BCE): 0.0756
# Epoch [997/2000] | Loss(BCE): 0.0620
# Epoch [998/2000] | Loss(BCE): 0.0709
# Epoch [999/2000] | Loss(BCE): 0.0735
# Epoch [1000/2000] | Loss(BCE): 0.0703
# Epoch [1001/2000] | Loss(BCE): 0.0730
# Epoch [1002/2000] | Loss(BCE): 0.0633
# Epoch [1003/2000] | Loss(BCE): 0.0714
# Epoch [1004/2000] | Loss(BCE): 0.0872
# Epoch [1005/2000] | Loss(BCE): 0.0619
# Epoch [1006/2000] | Loss(BCE): 0.0578
# Epoch [1007/2000] | Loss(BCE): 0.0689
# Epoch [1008/2000] | Loss(BCE): 0.0804
# Epoch [1009/2000] | Loss(BCE): 0.0608
# Epoch [1010/2000] | Loss(BCE): 0.0745
# Epoch [1011/2000] | Loss(BCE): 0.0596
# Epoch [1012/2000] | Loss(BCE): 0.0729
# Epoch [1013/2000] | Loss(BCE): 0.0714
# Epoch [1014/2000] | Loss(BCE): 0.0695
# Epoch [1015/2000] | Loss(BCE): 0.0711
# Epoch [1016/2000] | Loss(BCE): 0.0691
# Epoch [1017/2000] | Loss(BCE): 0.0669
# Epoch [1018/2000] | Loss(BCE): 0.0777
# Epoch [1019/2000] | Loss(BCE): 0.0775
# Epoch [1020/2000] | Loss(BCE): 0.0667
# Epoch [1021/2000] | Loss(BCE): 0.0603
# Epoch [1022/2000] | Loss(BCE): 0.0640
# Epoch [1023/2000] | Loss(BCE): 0.0737
# Epoch [1024/2000] | Loss(BCE): 0.0679
# Epoch [1025/2000] | Loss(BCE): 0.0754
# Epoch [1026/2000] | Loss(BCE): 0.0822
# Epoch [1027/2000] | Loss(BCE): 0.0664
# Epoch [1028/2000] | Loss(BCE): 0.0693
# Epoch [1029/2000] | Loss(BCE): 0.0663
# Epoch [1030/2000] | Loss(BCE): 0.0640
# Epoch [1031/2000] | Loss(BCE): 0.0713
# Epoch [1032/2000] | Loss(BCE): 0.0761
# Epoch [1033/2000] | Loss(BCE): 0.0725
# Epoch [1034/2000] | Loss(BCE): 0.0776
# Epoch [1035/2000] | Loss(BCE): 0.0660
# Epoch [1036/2000] | Loss(BCE): 0.0632
# Epoch [1037/2000] | Loss(BCE): 0.0649
# Epoch [1038/2000] | Loss(BCE): 0.0691
# Epoch [1039/2000] | Loss(BCE): 0.0573
# Epoch [1040/2000] | Loss(BCE): 0.0705
# Epoch [1041/2000] | Loss(BCE): 0.0704
# Epoch [1042/2000] | Loss(BCE): 0.0756
# Epoch [1043/2000] | Loss(BCE): 0.0731
# Epoch [1044/2000] | Loss(BCE): 0.0790
# Epoch [1045/2000] | Loss(BCE): 0.0643
# Epoch [1046/2000] | Loss(BCE): 0.0596
# Epoch [1047/2000] | Loss(BCE): 0.0778
# Epoch [1048/2000] | Loss(BCE): 0.0657
# Epoch [1049/2000] | Loss(BCE): 0.0586
# Epoch [1050/2000] | Loss(BCE): 0.0611
# Epoch [1051/2000] | Loss(BCE): 0.0688
# Epoch [1052/2000] | Loss(BCE): 0.0624
# Epoch [1053/2000] | Loss(BCE): 0.0676
# Epoch [1054/2000] | Loss(BCE): 0.0587
# Epoch [1055/2000] | Loss(BCE): 0.0692
# Epoch [1056/2000] | Loss(BCE): 0.0599
# Epoch [1057/2000] | Loss(BCE): 0.0733
# Epoch [1058/2000] | Loss(BCE): 0.0646
# Epoch [1059/2000] | Loss(BCE): 0.0596
# Epoch [1060/2000] | Loss(BCE): 0.0637
# Epoch [1061/2000] | Loss(BCE): 0.0697
# Epoch [1062/2000] | Loss(BCE): 0.0631
# Epoch [1063/2000] | Loss(BCE): 0.0660
# Epoch [1064/2000] | Loss(BCE): 0.0671
# Epoch [1065/2000] | Loss(BCE): 0.0690
# Epoch [1066/2000] | Loss(BCE): 0.0712
# Epoch [1067/2000] | Loss(BCE): 0.0673
# Epoch [1068/2000] | Loss(BCE): 0.0617
# Epoch [1069/2000] | Loss(BCE): 0.0766
# Epoch [1070/2000] | Loss(BCE): 0.0683
# Epoch [1071/2000] | Loss(BCE): 0.0793
# Epoch [1072/2000] | Loss(BCE): 0.0694
# Epoch [1073/2000] | Loss(BCE): 0.0726
# Epoch [1074/2000] | Loss(BCE): 0.0660
# Epoch [1075/2000] | Loss(BCE): 0.0630
# Epoch [1076/2000] | Loss(BCE): 0.0630
# Epoch [1077/2000] | Loss(BCE): 0.0782
# Epoch [1078/2000] | Loss(BCE): 0.0680
# Epoch [1079/2000] | Loss(BCE): 0.0673
# Epoch [1080/2000] | Loss(BCE): 0.0696
# Epoch [1081/2000] | Loss(BCE): 0.0706
# Epoch [1082/2000] | Loss(BCE): 0.0579
# Epoch [1083/2000] | Loss(BCE): 0.0678
# Epoch [1084/2000] | Loss(BCE): 0.0573
# Epoch [1085/2000] | Loss(BCE): 0.0686
# Epoch [1086/2000] | Loss(BCE): 0.0681
# Epoch [1087/2000] | Loss(BCE): 0.0719
# Epoch [1088/2000] | Loss(BCE): 0.0684
# Epoch [1089/2000] | Loss(BCE): 0.0595
# Epoch [1090/2000] | Loss(BCE): 0.0635
# Epoch [1091/2000] | Loss(BCE): 0.0682
# Epoch [1092/2000] | Loss(BCE): 0.0616
# Epoch [1093/2000] | Loss(BCE): 0.0768
# Epoch [1094/2000] | Loss(BCE): 0.0622
# Epoch [1095/2000] | Loss(BCE): 0.0586
# Epoch [1096/2000] | Loss(BCE): 0.0606
# Epoch [1097/2000] | Loss(BCE): 0.0606
# Epoch [1098/2000] | Loss(BCE): 0.0650
# Epoch [1099/2000] | Loss(BCE): 0.0792
# Epoch [1100/2000] | Loss(BCE): 0.0741
# Epoch [1101/2000] | Loss(BCE): 0.0714
# Epoch [1102/2000] | Loss(BCE): 0.0703
# Epoch [1103/2000] | Loss(BCE): 0.0689
# Epoch [1104/2000] | Loss(BCE): 0.0642
# Epoch [1105/2000] | Loss(BCE): 0.0681
# Epoch [1106/2000] | Loss(BCE): 0.0695
# Epoch [1107/2000] | Loss(BCE): 0.0621
# Epoch [1108/2000] | Loss(BCE): 0.0667
# Epoch [1109/2000] | Loss(BCE): 0.0670
# Epoch [1110/2000] | Loss(BCE): 0.0767
# Epoch [1111/2000] | Loss(BCE): 0.0754
# Epoch [1112/2000] | Loss(BCE): 0.0687
# Epoch [1113/2000] | Loss(BCE): 0.0689
# Epoch [1114/2000] | Loss(BCE): 0.0606
# Epoch [1115/2000] | Loss(BCE): 0.0731
# Epoch [1116/2000] | Loss(BCE): 0.0720
# Epoch [1117/2000] | Loss(BCE): 0.0680
# Epoch [1118/2000] | Loss(BCE): 0.0583
# Epoch [1119/2000] | Loss(BCE): 0.0550
# Epoch [1120/2000] | Loss(BCE): 0.0721
# Epoch [1121/2000] | Loss(BCE): 0.0757
# Epoch [1122/2000] | Loss(BCE): 0.0671
# Epoch [1123/2000] | Loss(BCE): 0.0654
# Epoch [1124/2000] | Loss(BCE): 0.0616
# Epoch [1125/2000] | Loss(BCE): 0.0658
# Epoch [1126/2000] | Loss(BCE): 0.0515
# Epoch [1127/2000] | Loss(BCE): 0.0587
# Epoch [1128/2000] | Loss(BCE): 0.0778
# Epoch [1129/2000] | Loss(BCE): 0.0749
# Epoch [1130/2000] | Loss(BCE): 0.0685
# Epoch [1131/2000] | Loss(BCE): 0.0619
# Epoch [1132/2000] | Loss(BCE): 0.0740
# Epoch [1133/2000] | Loss(BCE): 0.0699
# Epoch [1134/2000] | Loss(BCE): 0.0666
# Epoch [1135/2000] | Loss(BCE): 0.0612
# Epoch [1136/2000] | Loss(BCE): 0.0666
# Epoch [1137/2000] | Loss(BCE): 0.0611
# Epoch [1138/2000] | Loss(BCE): 0.0603
# Epoch [1139/2000] | Loss(BCE): 0.0606
# Epoch [1140/2000] | Loss(BCE): 0.0612
# Epoch [1141/2000] | Loss(BCE): 0.0685
# Epoch [1142/2000] | Loss(BCE): 0.0635
# Epoch [1143/2000] | Loss(BCE): 0.0632
# Epoch [1144/2000] | Loss(BCE): 0.0541
# Epoch [1145/2000] | Loss(BCE): 0.0695
# Epoch [1146/2000] | Loss(BCE): 0.0738
# Epoch [1147/2000] | Loss(BCE): 0.0535
# Epoch [1148/2000] | Loss(BCE): 0.0621
# Epoch [1149/2000] | Loss(BCE): 0.0695
# Epoch [1150/2000] | Loss(BCE): 0.0613
# Epoch [1151/2000] | Loss(BCE): 0.0622
# Epoch [1152/2000] | Loss(BCE): 0.0695
# Epoch [1153/2000] | Loss(BCE): 0.0607
# Epoch [1154/2000] | Loss(BCE): 0.0626
# Epoch [1155/2000] | Loss(BCE): 0.0723
# Epoch [1156/2000] | Loss(BCE): 0.0648
# Epoch [1157/2000] | Loss(BCE): 0.0616
# Epoch [1158/2000] | Loss(BCE): 0.0654
# Epoch [1159/2000] | Loss(BCE): 0.0576
# Epoch [1160/2000] | Loss(BCE): 0.0660
# Epoch [1161/2000] | Loss(BCE): 0.0756
# Epoch [1162/2000] | Loss(BCE): 0.0664
# Epoch [1163/2000] | Loss(BCE): 0.0565
# Epoch [1164/2000] | Loss(BCE): 0.0676
# Epoch [1165/2000] | Loss(BCE): 0.0637
# Epoch [1166/2000] | Loss(BCE): 0.0659
# Epoch [1167/2000] | Loss(BCE): 0.0600
# Epoch [1168/2000] | Loss(BCE): 0.0682
# Epoch [1169/2000] | Loss(BCE): 0.0685
# Epoch [1170/2000] | Loss(BCE): 0.0664
# Epoch [1171/2000] | Loss(BCE): 0.0641
# Epoch [1172/2000] | Loss(BCE): 0.0687
# Epoch [1173/2000] | Loss(BCE): 0.0642
# Epoch [1174/2000] | Loss(BCE): 0.0602
# Epoch [1175/2000] | Loss(BCE): 0.0632
# Epoch [1176/2000] | Loss(BCE): 0.0652
# Epoch [1177/2000] | Loss(BCE): 0.0679
# Epoch [1178/2000] | Loss(BCE): 0.0614
# Epoch [1179/2000] | Loss(BCE): 0.0614
# Epoch [1180/2000] | Loss(BCE): 0.0670
# Epoch [1181/2000] | Loss(BCE): 0.0694
# Epoch [1182/2000] | Loss(BCE): 0.0570
# Epoch [1183/2000] | Loss(BCE): 0.0709
# Epoch [1184/2000] | Loss(BCE): 0.0635
# Epoch [1185/2000] | Loss(BCE): 0.0645
# Epoch [1186/2000] | Loss(BCE): 0.0652
# Epoch [1187/2000] | Loss(BCE): 0.0580
# Epoch [1188/2000] | Loss(BCE): 0.0582
# Epoch [1189/2000] | Loss(BCE): 0.0638
# Epoch [1190/2000] | Loss(BCE): 0.0657
# Epoch [1191/2000] | Loss(BCE): 0.0561
# Epoch [1192/2000] | Loss(BCE): 0.0762
# Epoch [1193/2000] | Loss(BCE): 0.0674
# Epoch [1194/2000] | Loss(BCE): 0.0589
# Epoch [1195/2000] | Loss(BCE): 0.0674
# Epoch [1196/2000] | Loss(BCE): 0.0619
# Epoch [1197/2000] | Loss(BCE): 0.0688
# Epoch [1198/2000] | Loss(BCE): 0.0747
# Epoch [1199/2000] | Loss(BCE): 0.0649
# Epoch [1200/2000] | Loss(BCE): 0.0658
# Epoch [1201/2000] | Loss(BCE): 0.0623
# Epoch [1202/2000] | Loss(BCE): 0.0549
# Epoch [1203/2000] | Loss(BCE): 0.0685
# Epoch [1204/2000] | Loss(BCE): 0.0763
# Epoch [1205/2000] | Loss(BCE): 0.0769
# Epoch [1206/2000] | Loss(BCE): 0.0731
# Epoch [1207/2000] | Loss(BCE): 0.0605
# Epoch [1208/2000] | Loss(BCE): 0.0684
# Epoch [1209/2000] | Loss(BCE): 0.0628
# Epoch [1210/2000] | Loss(BCE): 0.0624
# Epoch [1211/2000] | Loss(BCE): 0.0611
# Epoch [1212/2000] | Loss(BCE): 0.0599
# Epoch [1213/2000] | Loss(BCE): 0.0635
# Epoch [1214/2000] | Loss(BCE): 0.0613
# Epoch [1215/2000] | Loss(BCE): 0.0654
# Epoch [1216/2000] | Loss(BCE): 0.0668
# Epoch [1217/2000] | Loss(BCE): 0.0728
# Epoch [1218/2000] | Loss(BCE): 0.0704
# Epoch [1219/2000] | Loss(BCE): 0.0675
# Epoch [1220/2000] | Loss(BCE): 0.0542
# Epoch [1221/2000] | Loss(BCE): 0.0621
# Epoch [1222/2000] | Loss(BCE): 0.0536
# Epoch [1223/2000] | Loss(BCE): 0.0667
# Epoch [1224/2000] | Loss(BCE): 0.0709
# Epoch [1225/2000] | Loss(BCE): 0.0565
# Epoch [1226/2000] | Loss(BCE): 0.0566
# Epoch [1227/2000] | Loss(BCE): 0.0601
# Epoch [1228/2000] | Loss(BCE): 0.0582
# Epoch [1229/2000] | Loss(BCE): 0.0561
# Epoch [1230/2000] | Loss(BCE): 0.0586
# Epoch [1231/2000] | Loss(BCE): 0.0634
# Epoch [1232/2000] | Loss(BCE): 0.0810
# Epoch [1233/2000] | Loss(BCE): 0.0789
# Epoch [1234/2000] | Loss(BCE): 0.0556
# Epoch [1235/2000] | Loss(BCE): 0.0777
# Epoch [1236/2000] | Loss(BCE): 0.0513
# Epoch [1237/2000] | Loss(BCE): 0.0594
# Epoch [1238/2000] | Loss(BCE): 0.0692
# Epoch [1239/2000] | Loss(BCE): 0.0776
# Epoch [1240/2000] | Loss(BCE): 0.0652
# Epoch [1241/2000] | Loss(BCE): 0.0622
# Epoch [1242/2000] | Loss(BCE): 0.0622
# Epoch [1243/2000] | Loss(BCE): 0.0807
# Epoch [1244/2000] | Loss(BCE): 0.0717
# Epoch [1245/2000] | Loss(BCE): 0.0689
# Epoch [1246/2000] | Loss(BCE): 0.0623
# Epoch [1247/2000] | Loss(BCE): 0.0671
# Epoch [1248/2000] | Loss(BCE): 0.0688
# Epoch [1249/2000] | Loss(BCE): 0.0600
# Epoch [1250/2000] | Loss(BCE): 0.0528
# Epoch [1251/2000] | Loss(BCE): 0.0624
# Epoch [1252/2000] | Loss(BCE): 0.0611
# Epoch [1253/2000] | Loss(BCE): 0.0736
# Epoch [1254/2000] | Loss(BCE): 0.0596
# Epoch [1255/2000] | Loss(BCE): 0.0591
# Epoch [1256/2000] | Loss(BCE): 0.0707
# Epoch [1257/2000] | Loss(BCE): 0.0595
# Epoch [1258/2000] | Loss(BCE): 0.0647
# Epoch [1259/2000] | Loss(BCE): 0.0590
# Epoch [1260/2000] | Loss(BCE): 0.0737
# Epoch [1261/2000] | Loss(BCE): 0.0703
# Epoch [1262/2000] | Loss(BCE): 0.0593
# Epoch [1263/2000] | Loss(BCE): 0.0697
# Epoch [1264/2000] | Loss(BCE): 0.0658
# Epoch [1265/2000] | Loss(BCE): 0.0524
# Epoch [1266/2000] | Loss(BCE): 0.0570
# Epoch [1267/2000] | Loss(BCE): 0.0628
# Epoch [1268/2000] | Loss(BCE): 0.0695
# Epoch [1269/2000] | Loss(BCE): 0.0562
# Epoch [1270/2000] | Loss(BCE): 0.0634
# Epoch [1271/2000] | Loss(BCE): 0.0611
# Epoch [1272/2000] | Loss(BCE): 0.0695
# Epoch [1273/2000] | Loss(BCE): 0.0718
# Epoch [1274/2000] | Loss(BCE): 0.0523
# Epoch [1275/2000] | Loss(BCE): 0.0656
# Epoch [1276/2000] | Loss(BCE): 0.0595
# Epoch [1277/2000] | Loss(BCE): 0.0775
# Epoch [1278/2000] | Loss(BCE): 0.0580
# Epoch [1279/2000] | Loss(BCE): 0.0662
# Epoch [1280/2000] | Loss(BCE): 0.0685
# Epoch [1281/2000] | Loss(BCE): 0.0576
# Epoch [1282/2000] | Loss(BCE): 0.0635
# Epoch [1283/2000] | Loss(BCE): 0.0578
# Epoch [1284/2000] | Loss(BCE): 0.0541
# Epoch [1285/2000] | Loss(BCE): 0.0580
# Epoch [1286/2000] | Loss(BCE): 0.0666
# Epoch [1287/2000] | Loss(BCE): 0.0578
# Epoch [1288/2000] | Loss(BCE): 0.0605
# Epoch [1289/2000] | Loss(BCE): 0.0673
# Epoch [1290/2000] | Loss(BCE): 0.0635
# Epoch [1291/2000] | Loss(BCE): 0.0602
# Epoch [1292/2000] | Loss(BCE): 0.0525
# Epoch [1293/2000] | Loss(BCE): 0.0694
# Epoch [1294/2000] | Loss(BCE): 0.0579
# Epoch [1295/2000] | Loss(BCE): 0.0657
# ...
# Epoch [1580/2000] | Loss(BCE): 0.0648
# Epoch [1581/2000] | Loss(BCE): 0.0648
# Epoch [1582/2000] | Loss(BCE): 0.0603
# Epoch [1583/2000] | Loss(BCE): 0.0639
# Epoch [1584/2000] | Loss(BCE): 0.0608
# Epoch [1585/2000] | Loss(BCE): 0.0551
# Epoch [1586/2000] | Loss(BCE): 0.0768
# Epoch [1587/2000] | Loss(BCE): 0.0553
# Epoch [1588/2000] | Loss(BCE): 0.0585
# Epoch [1589/2000] | Loss(BCE): 0.0656
# Epoch [1590/2000] | Loss(BCE): 0.0483
# Epoch [1591/2000] | Loss(BCE): 0.0659
# Epoch [1592/2000] | Loss(BCE): 0.0565
# Epoch [1593/2000] | Loss(BCE): 0.0595
# Epoch [1594/2000] | Loss(BCE): 0.0575
# Epoch [1595/2000] | Loss(BCE): 0.0556
# Epoch [1596/2000] | Loss(BCE): 0.0644
# Epoch [1597/2000] | Loss(BCE): 0.0676
# Epoch [1598/2000] | Loss(BCE): 0.0646
# Epoch [1599/2000] | Loss(BCE): 0.0646
# Epoch [1600/2000] | Loss(BCE): 0.0558
# Epoch [1601/2000] | Loss(BCE): 0.0594
# Epoch [1602/2000] | Loss(BCE): 0.0630
# Epoch [1603/2000] | Loss(BCE): 0.0646
# Epoch [1604/2000] | Loss(BCE): 0.0545
# Epoch [1605/2000] | Loss(BCE): 0.0511
# Epoch [1606/2000] | Loss(BCE): 0.0643
# Epoch [1607/2000] | Loss(BCE): 0.0593
# Epoch [1608/2000] | Loss(BCE): 0.0568
# Epoch [1609/2000] | Loss(BCE): 0.0633
# Epoch [1610/2000] | Loss(BCE): 0.0539
# Epoch [1611/2000] | Loss(BCE): 0.0656
# Epoch [1612/2000] | Loss(BCE): 0.0557
# Epoch [1613/2000] | Loss(BCE): 0.0534
# Epoch [1614/2000] | Loss(BCE): 0.0669
# Epoch [1615/2000] | Loss(BCE): 0.0601
# Epoch [1616/2000] | Loss(BCE): 0.0550
# Epoch [1617/2000] | Loss(BCE): 0.0596
# Epoch [1618/2000] | Loss(BCE): 0.0540
# Epoch [1619/2000] | Loss(BCE): 0.0553
# Epoch [1620/2000] | Loss(BCE): 0.0554
# Epoch [1621/2000] | Loss(BCE): 0.0531
# Epoch [1622/2000] | Loss(BCE): 0.0556
# Epoch [1623/2000] | Loss(BCE): 0.0481
# Epoch [1624/2000] | Loss(BCE): 0.0524
# Epoch [1625/2000] | Loss(BCE): 0.0485
# Epoch [1626/2000] | Loss(BCE): 0.0609
# Epoch [1627/2000] | Loss(BCE): 0.0622
# Epoch [1628/2000] | Loss(BCE): 0.0493
# Epoch [1629/2000] | Loss(BCE): 0.0604
# Epoch [1630/2000] | Loss(BCE): 0.0449
# Epoch [1631/2000] | Loss(BCE): 0.0568
# Epoch [1632/2000] | Loss(BCE): 0.0502
# Epoch [1633/2000] | Loss(BCE): 0.0631
# Epoch [1634/2000] | Loss(BCE): 0.0574
# Epoch [1635/2000] | Loss(BCE): 0.0621
# Epoch [1636/2000] | Loss(BCE): 0.0595
# Epoch [1637/2000] | Loss(BCE): 0.0574
# Epoch [1638/2000] | Loss(BCE): 0.0587
# Epoch [1639/2000] | Loss(BCE): 0.0586
# Epoch [1640/2000] | Loss(BCE): 0.0639
# Epoch [1641/2000] | Loss(BCE): 0.0467
# Epoch [1642/2000] | Loss(BCE): 0.0535
# Epoch [1643/2000] | Loss(BCE): 0.0560
# Epoch [1644/2000] | Loss(BCE): 0.0619
# Epoch [1645/2000] | Loss(BCE): 0.0550
# Epoch [1646/2000] | Loss(BCE): 0.0629
# Epoch [1647/2000] | Loss(BCE): 0.0620
# Epoch [1648/2000] | Loss(BCE): 0.0554
# Epoch [1649/2000] | Loss(BCE): 0.0570
# Epoch [1650/2000] | Loss(BCE): 0.0662
# Epoch [1651/2000] | Loss(BCE): 0.0615
# Epoch [1652/2000] | Loss(BCE): 0.0647
# Epoch [1653/2000] | Loss(BCE): 0.0607
# Epoch [1654/2000] | Loss(BCE): 0.0624
# Epoch [1655/2000] | Loss(BCE): 0.0573
# Epoch [1656/2000] | Loss(BCE): 0.0535
# Epoch [1657/2000] | Loss(BCE): 0.0604
# Epoch [1658/2000] | Loss(BCE): 0.0548
# Epoch [1659/2000] | Loss(BCE): 0.0594
# Epoch [1660/2000] | Loss(BCE): 0.0551
# Epoch [1661/2000] | Loss(BCE): 0.0524
# Epoch [1662/2000] | Loss(BCE): 0.0539
# Epoch [1663/2000] | Loss(BCE): 0.0527
# Epoch [1664/2000] | Loss(BCE): 0.0561
# Epoch [1665/2000] | Loss(BCE): 0.0554
# Epoch [1666/2000] | Loss(BCE): 0.0543
# Epoch [1667/2000] | Loss(BCE): 0.0553
# Epoch [1668/2000] | Loss(BCE): 0.0587
# Epoch [1669/2000] | Loss(BCE): 0.0585
# Epoch [1670/2000] | Loss(BCE): 0.0575
# Epoch [1671/2000] | Loss(BCE): 0.0589
# Epoch [1672/2000] | Loss(BCE): 0.0651
# Epoch [1673/2000] | Loss(BCE): 0.0623
# Epoch [1674/2000] | Loss(BCE): 0.0537
# Epoch [1675/2000] | Loss(BCE): 0.0568
# Epoch [1676/2000] | Loss(BCE): 0.0620
# Epoch [1677/2000] | Loss(BCE): 0.0547
# Epoch [1678/2000] | Loss(BCE): 0.0535
# Epoch [1679/2000] | Loss(BCE): 0.0555
# Epoch [1680/2000] | Loss(BCE): 0.0617
# Epoch [1681/2000] | Loss(BCE): 0.0531
# Epoch [1682/2000] | Loss(BCE): 0.0559
# Epoch [1683/2000] | Loss(BCE): 0.0546
# Epoch [1684/2000] | Loss(BCE): 0.0606
# Epoch [1685/2000] | Loss(BCE): 0.0590
# Epoch [1686/2000] | Loss(BCE): 0.0466
# Epoch [1687/2000] | Loss(BCE): 0.0495
# Epoch [1688/2000] | Loss(BCE): 0.0505
# Epoch [1689/2000] | Loss(BCE): 0.0541
# Epoch [1690/2000] | Loss(BCE): 0.0500
# Epoch [1691/2000] | Loss(BCE): 0.0551
# Epoch [1692/2000] | Loss(BCE): 0.0577
# Epoch [1693/2000] | Loss(BCE): 0.0618
# Epoch [1694/2000] | Loss(BCE): 0.0730
# Epoch [1695/2000] | Loss(BCE): 0.0560
# Epoch [1696/2000] | Loss(BCE): 0.0506
# Epoch [1697/2000] | Loss(BCE): 0.0579
# Epoch [1698/2000] | Loss(BCE): 0.0520
# Epoch [1699/2000] | Loss(BCE): 0.0652
# Epoch [1700/2000] | Loss(BCE): 0.0500
# Epoch [1701/2000] | Loss(BCE): 0.0564
# Epoch [1702/2000] | Loss(BCE): 0.0549
# Epoch [1703/2000] | Loss(BCE): 0.0584
# Epoch [1704/2000] | Loss(BCE): 0.0555
# Epoch [1705/2000] | Loss(BCE): 0.0489
# Epoch [1706/2000] | Loss(BCE): 0.0475
# Epoch [1707/2000] | Loss(BCE): 0.0588
# Epoch [1708/2000] | Loss(BCE): 0.0697
# Epoch [1709/2000] | Loss(BCE): 0.0550
# Epoch [1710/2000] | Loss(BCE): 0.0535
# Epoch [1711/2000] | Loss(BCE): 0.0548
# Epoch [1712/2000] | Loss(BCE): 0.0599
# Epoch [1713/2000] | Loss(BCE): 0.0470
# Epoch [1714/2000] | Loss(BCE): 0.0618
# Epoch [1715/2000] | Loss(BCE): 0.0571
# Epoch [1716/2000] | Loss(BCE): 0.0542
# Epoch [1717/2000] | Loss(BCE): 0.0492
# Epoch [1718/2000] | Loss(BCE): 0.0588
# Epoch [1719/2000] | Loss(BCE): 0.0651
# Epoch [1720/2000] | Loss(BCE): 0.0540
# Epoch [1721/2000] | Loss(BCE): 0.0606
# Epoch [1722/2000] | Loss(BCE): 0.0620
# Epoch [1723/2000] | Loss(BCE): 0.0491
# Epoch [1724/2000] | Loss(BCE): 0.0614
# Epoch [1725/2000] | Loss(BCE): 0.0549
# Epoch [1726/2000] | Loss(BCE): 0.0499
# Epoch [1727/2000] | Loss(BCE): 0.0568
# Epoch [1728/2000] | Loss(BCE): 0.0504
# Epoch [1729/2000] | Loss(BCE): 0.0601
# Epoch [1730/2000] | Loss(BCE): 0.0517
# Epoch [1731/2000] | Loss(BCE): 0.0619
# Epoch [1732/2000] | Loss(BCE): 0.0472
# Epoch [1733/2000] | Loss(BCE): 0.0545
# Epoch [1734/2000] | Loss(BCE): 0.0547
# Epoch [1735/2000] | Loss(BCE): 0.0582
# Epoch [1736/2000] | Loss(BCE): 0.0560
# Epoch [1737/2000] | Loss(BCE): 0.0501
# Epoch [1738/2000] | Loss(BCE): 0.0558
# Epoch [1739/2000] | Loss(BCE): 0.0663
# Epoch [1740/2000] | Loss(BCE): 0.0665
# Epoch [1741/2000] | Loss(BCE): 0.0503
# Epoch [1742/2000] | Loss(BCE): 0.0518
# Epoch [1743/2000] | Loss(BCE): 0.0580
# Epoch [1744/2000] | Loss(BCE): 0.0525
# Epoch [1745/2000] | Loss(BCE): 0.0547
# Epoch [1746/2000] | Loss(BCE): 0.0580
# Epoch [1747/2000] | Loss(BCE): 0.0516
# Epoch [1748/2000] | Loss(BCE): 0.0624
# Epoch [1749/2000] | Loss(BCE): 0.0539
# Epoch [1750/2000] | Loss(BCE): 0.0491
# Epoch [1751/2000] | Loss(BCE): 0.0598
# Epoch [1752/2000] | Loss(BCE): 0.0516
# Epoch [1753/2000] | Loss(BCE): 0.0460
# Epoch [1754/2000] | Loss(BCE): 0.0545
# Epoch [1755/2000] | Loss(BCE): 0.0646
# Epoch [1756/2000] | Loss(BCE): 0.0445
# Epoch [1757/2000] | Loss(BCE): 0.0500
# Epoch [1758/2000] | Loss(BCE): 0.0589
# Epoch [1759/2000] | Loss(BCE): 0.0618
# Epoch [1760/2000] | Loss(BCE): 0.0506
# Epoch [1761/2000] | Loss(BCE): 0.0591
# Epoch [1762/2000] | Loss(BCE): 0.0522
# Epoch [1763/2000] | Loss(BCE): 0.0581
# Epoch [1764/2000] | Loss(BCE): 0.0506
# Epoch [1765/2000] | Loss(BCE): 0.0562
# Epoch [1766/2000] | Loss(BCE): 0.0551
# Epoch [1767/2000] | Loss(BCE): 0.0523
# Epoch [1768/2000] | Loss(BCE): 0.0541
# Epoch [1769/2000] | Loss(BCE): 0.0548
# Epoch [1770/2000] | Loss(BCE): 0.0558
# Epoch [1771/2000] | Loss(BCE): 0.0579
# Epoch [1772/2000] | Loss(BCE): 0.0526
# Epoch [1773/2000] | Loss(BCE): 0.0638
# Epoch [1774/2000] | Loss(BCE): 0.0675
# Epoch [1775/2000] | Loss(BCE): 0.0639
# Epoch [1776/2000] | Loss(BCE): 0.0521
# Epoch [1777/2000] | Loss(BCE): 0.0515
# Epoch [1778/2000] | Loss(BCE): 0.0682
# Epoch [1779/2000] | Loss(BCE): 0.0551
# Epoch [1780/2000] | Loss(BCE): 0.0522
# Epoch [1781/2000] | Loss(BCE): 0.0509
# Epoch [1782/2000] | Loss(BCE): 0.0522
# Epoch [1783/2000] | Loss(BCE): 0.0563
# Epoch [1784/2000] | Loss(BCE): 0.0563
# Epoch [1785/2000] | Loss(BCE): 0.0610
# Epoch [1786/2000] | Loss(BCE): 0.0506
# Epoch [1787/2000] | Loss(BCE): 0.0526
# Epoch [1788/2000] | Loss(BCE): 0.0572
# Epoch [1789/2000] | Loss(BCE): 0.0540
# Epoch [1790/2000] | Loss(BCE): 0.0523
# Epoch [1791/2000] | Loss(BCE): 0.0624
# Epoch [1792/2000] | Loss(BCE): 0.0581
# Epoch [1793/2000] | Loss(BCE): 0.0520
# Epoch [1794/2000] | Loss(BCE): 0.0569
# Epoch [1795/2000] | Loss(BCE): 0.0531
# Epoch [1796/2000] | Loss(BCE): 0.0566
# Epoch [1797/2000] | Loss(BCE): 0.0485
# Epoch [1798/2000] | Loss(BCE): 0.0544
# Epoch [1799/2000] | Loss(BCE): 0.0544
# Epoch [1800/2000] | Loss(BCE): 0.0583
# Epoch [1801/2000] | Loss(BCE): 0.0532
# Epoch [1802/2000] | Loss(BCE): 0.0549
# Epoch [1803/2000] | Loss(BCE): 0.0569
# Epoch [1804/2000] | Loss(BCE): 0.0516
# Epoch [1805/2000] | Loss(BCE): 0.0599
# Epoch [1806/2000] | Loss(BCE): 0.0558
# Epoch [1807/2000] | Loss(BCE): 0.0621
# Epoch [1808/2000] | Loss(BCE): 0.0526
# Epoch [1809/2000] | Loss(BCE): 0.0544
# Epoch [1810/2000] | Loss(BCE): 0.0672
# Epoch [1811/2000] | Loss(BCE): 0.0487
# Epoch [1812/2000] | Loss(BCE): 0.0569
# Epoch [1813/2000] | Loss(BCE): 0.0568
# Epoch [1814/2000] | Loss(BCE): 0.0507
# Epoch [1815/2000] | Loss(BCE): 0.0563
# Epoch [1816/2000] | Loss(BCE): 0.0499
# Epoch [1817/2000] | Loss(BCE): 0.0559
# Epoch [1818/2000] | Loss(BCE): 0.0587
# Epoch [1819/2000] | Loss(BCE): 0.0572
# Epoch [1820/2000] | Loss(BCE): 0.0588
# Epoch [1821/2000] | Loss(BCE): 0.0661
# Epoch [1822/2000] | Loss(BCE): 0.0538
# Epoch [1823/2000] | Loss(BCE): 0.0463
# Epoch [1824/2000] | Loss(BCE): 0.0518
# Epoch [1825/2000] | Loss(BCE): 0.0615
# Epoch [1826/2000] | Loss(BCE): 0.0492
# Epoch [1827/2000] | Loss(BCE): 0.0493
# Epoch [1828/2000] | Loss(BCE): 0.0523
# Epoch [1829/2000] | Loss(BCE): 0.0587
# Epoch [1830/2000] | Loss(BCE): 0.0547
# Epoch [1831/2000] | Loss(BCE): 0.0558
# Epoch [1832/2000] | Loss(BCE): 0.0589
# Epoch [1833/2000] | Loss(BCE): 0.0493
# Epoch [1834/2000] | Loss(BCE): 0.0627
# Epoch [1835/2000] | Loss(BCE): 0.0537
# Epoch [1836/2000] | Loss(BCE): 0.0678
# Epoch [1837/2000] | Loss(BCE): 0.0540
# Epoch [1838/2000] | Loss(BCE): 0.0666
# Epoch [1839/2000] | Loss(BCE): 0.0559
# Epoch [1840/2000] | Loss(BCE): 0.0561
# Epoch [1841/2000] | Loss(BCE): 0.0568
# Epoch [1842/2000] | Loss(BCE): 0.0521
# Epoch [1843/2000] | Loss(BCE): 0.0427
# Epoch [1844/2000] | Loss(BCE): 0.0556
# Epoch [1845/2000] | Loss(BCE): 0.0575
# Epoch [1846/2000] | Loss(BCE): 0.0515
# Epoch [1847/2000] | Loss(BCE): 0.0639
# Epoch [1848/2000] | Loss(BCE): 0.0552
# Epoch [1849/2000] | Loss(BCE): 0.0503
# Epoch [1850/2000] | Loss(BCE): 0.0579
# Epoch [1851/2000] | Loss(BCE): 0.0565
# Epoch [1852/2000] | Loss(BCE): 0.0521
# Epoch [1853/2000] | Loss(BCE): 0.0543
# Epoch [1854/2000] | Loss(BCE): 0.0567
# Epoch [1855/2000] | Loss(BCE): 0.0482
# Epoch [1856/2000] | Loss(BCE): 0.0540
# Epoch [1857/2000] | Loss(BCE): 0.0536
# Epoch [1858/2000] | Loss(BCE): 0.0533
# Epoch [1859/2000] | Loss(BCE): 0.0492
# Epoch [1860/2000] | Loss(BCE): 0.0532
# Epoch [1861/2000] | Loss(BCE): 0.0544
# Epoch [1862/2000] | Loss(BCE): 0.0480
# Epoch [1863/2000] | Loss(BCE): 0.0493
# Epoch [1864/2000] | Loss(BCE): 0.0532
# Epoch [1865/2000] | Loss(BCE): 0.0650
# Epoch [1866/2000] | Loss(BCE): 0.0605
# Epoch [1867/2000] | Loss(BCE): 0.0444
# Epoch [1868/2000] | Loss(BCE): 0.0604
# Epoch [1869/2000] | Loss(BCE): 0.0600
# Epoch [1870/2000] | Loss(BCE): 0.0526
# Epoch [1871/2000] | Loss(BCE): 0.0574
# Epoch [1872/2000] | Loss(BCE): 0.0437
# Epoch [1873/2000] | Loss(BCE): 0.0577
# Epoch [1874/2000] | Loss(BCE): 0.0529
# Epoch [1875/2000] | Loss(BCE): 0.0633
# Epoch [1876/2000] | Loss(BCE): 0.0602
# Epoch [1877/2000] | Loss(BCE): 0.0530
# Epoch [1878/2000] | Loss(BCE): 0.0514
# Epoch [1879/2000] | Loss(BCE): 0.0609
# Epoch [1880/2000] | Loss(BCE): 0.0534
# Epoch [1881/2000] | Loss(BCE): 0.0621
# Epoch [1882/2000] | Loss(BCE): 0.0544
# Epoch [1883/2000] | Loss(BCE): 0.0585
# Epoch [1884/2000] | Loss(BCE): 0.0525
# Epoch [1885/2000] | Loss(BCE): 0.0515
# Epoch [1886/2000] | Loss(BCE): 0.0518
# Epoch [1887/2000] | Loss(BCE): 0.0527
# Epoch [1888/2000] | Loss(BCE): 0.0548
# Epoch [1889/2000] | Loss(BCE): 0.0573
# Epoch [1890/2000] | Loss(BCE): 0.0542
# Epoch [1891/2000] | Loss(BCE): 0.0510
# Epoch [1892/2000] | Loss(BCE): 0.0592
# Epoch [1893/2000] | Loss(BCE): 0.0502
# Epoch [1894/2000] | Loss(BCE): 0.0568
# Epoch [1895/2000] | Loss(BCE): 0.0581
# Epoch [1896/2000] | Loss(BCE): 0.0672
# Epoch [1897/2000] | Loss(BCE): 0.0556
# Epoch [1898/2000] | Loss(BCE): 0.0608
# Epoch [1899/2000] | Loss(BCE): 0.0572
# Epoch [1900/2000] | Loss(BCE): 0.0594
# Epoch [1901/2000] | Loss(BCE): 0.0571
# Epoch [1902/2000] | Loss(BCE): 0.0573
# Epoch [1903/2000] | Loss(BCE): 0.0468
# Epoch [1904/2000] | Loss(BCE): 0.0502
# Epoch [1905/2000] | Loss(BCE): 0.0570
# Epoch [1906/2000] | Loss(BCE): 0.0647
# Epoch [1907/2000] | Loss(BCE): 0.0551
# Epoch [1908/2000] | Loss(BCE): 0.0495
# Epoch [1909/2000] | Loss(BCE): 0.0522
# Epoch [1910/2000] | Loss(BCE): 0.0549
# Epoch [1911/2000] | Loss(BCE): 0.0546
# Epoch [1912/2000] | Loss(BCE): 0.0587
# Epoch [1913/2000] | Loss(BCE): 0.0469
# Epoch [1914/2000] | Loss(BCE): 0.0490
# Epoch [1915/2000] | Loss(BCE): 0.0512
# Epoch [1916/2000] | Loss(BCE): 0.0445
# Epoch [1917/2000] | Loss(BCE): 0.0527
# Epoch [1918/2000] | Loss(BCE): 0.0522
# Epoch [1919/2000] | Loss(BCE): 0.0509
# Epoch [1920/2000] | Loss(BCE): 0.0481
# Epoch [1921/2000] | Loss(BCE): 0.0516
# Epoch [1922/2000] | Loss(BCE): 0.0532
# Epoch [1923/2000] | Loss(BCE): 0.0622
# Epoch [1924/2000] | Loss(BCE): 0.0554
# Epoch [1925/2000] | Loss(BCE): 0.0489
# Epoch [1926/2000] | Loss(BCE): 0.0527
# Epoch [1927/2000] | Loss(BCE): 0.0524
# Epoch [1928/2000] | Loss(BCE): 0.0557
# Epoch [1929/2000] | Loss(BCE): 0.0635
# Epoch [1930/2000] | Loss(BCE): 0.0589
# Epoch [1931/2000] | Loss(BCE): 0.0695
# Epoch [1932/2000] | Loss(BCE): 0.0593
# Epoch [1933/2000] | Loss(BCE): 0.0551
# Epoch [1934/2000] | Loss(BCE): 0.0543
# Epoch [1935/2000] | Loss(BCE): 0.0539
# Epoch [1936/2000] | Loss(BCE): 0.0572
# Epoch [1937/2000] | Loss(BCE): 0.0549
# Epoch [1938/2000] | Loss(BCE): 0.0628
# Epoch [1939/2000] | Loss(BCE): 0.0585
# Epoch [1940/2000] | Loss(BCE): 0.0504
# Epoch [1941/2000] | Loss(BCE): 0.0662
# Epoch [1942/2000] | Loss(BCE): 0.0534
# Epoch [1943/2000] | Loss(BCE): 0.0505
# Epoch [1944/2000] | Loss(BCE): 0.0597
# Epoch [1945/2000] | Loss(BCE): 0.0505
# Epoch [1946/2000] | Loss(BCE): 0.0505
# Epoch [1947/2000] | Loss(BCE): 0.0556
# Epoch [1948/2000] | Loss(BCE): 0.0503
# Epoch [1949/2000] | Loss(BCE): 0.0516
# Epoch [1950/2000] | Loss(BCE): 0.0471
# Epoch [1951/2000] | Loss(BCE): 0.0473
# Epoch [1952/2000] | Loss(BCE): 0.0453
# Epoch [1953/2000] | Loss(BCE): 0.0544
# Epoch [1954/2000] | Loss(BCE): 0.0493
# Epoch [1955/2000] | Loss(BCE): 0.0471
# Epoch [1956/2000] | Loss(BCE): 0.0588
# Epoch [1957/2000] | Loss(BCE): 0.0510
# Epoch [1958/2000] | Loss(BCE): 0.0571
# Epoch [1959/2000] | Loss(BCE): 0.0692
# Epoch [1960/2000] | Loss(BCE): 0.0594
# Epoch [1961/2000] | Loss(BCE): 0.0532
# Epoch [1962/2000] | Loss(BCE): 0.0607
# Epoch [1963/2000] | Loss(BCE): 0.0465
# Epoch [1964/2000] | Loss(BCE): 0.0583
# Epoch [1965/2000] | Loss(BCE): 0.0511
# Epoch [1966/2000] | Loss(BCE): 0.0555
# Epoch [1967/2000] | Loss(BCE): 0.0527
# Epoch [1968/2000] | Loss(BCE): 0.0531
# Epoch [1969/2000] | Loss(BCE): 0.0466
# Epoch [1970/2000] | Loss(BCE): 0.0517
# Epoch [1971/2000] | Loss(BCE): 0.0533
# Epoch [1972/2000] | Loss(BCE): 0.0522
# Epoch [1973/2000] | Loss(BCE): 0.0525
# Epoch [1974/2000] | Loss(BCE): 0.0542
# Epoch [1975/2000] | Loss(BCE): 0.0471
# Epoch [1976/2000] | Loss(BCE): 0.0595
# Epoch [1977/2000] | Loss(BCE): 0.0524
# Epoch [1978/2000] | Loss(BCE): 0.0545
# Epoch [1979/2000] | Loss(BCE): 0.0537
# Epoch [1980/2000] | Loss(BCE): 0.0519
# Epoch [1981/2000] | Loss(BCE): 0.0549
# Epoch [1982/2000] | Loss(BCE): 0.0485
# Epoch [1983/2000] | Loss(BCE): 0.0530
# Epoch [1984/2000] | Loss(BCE): 0.0539
# Epoch [1985/2000] | Loss(BCE): 0.0564
# Epoch [1986/2000] | Loss(BCE): 0.0510
# Epoch [1987/2000] | Loss(BCE): 0.0471
# Epoch [1988/2000] | Loss(BCE): 0.0517
# Epoch [1989/2000] | Loss(BCE): 0.0515
# Epoch [1990/2000] | Loss(BCE): 0.0550
# Epoch [1991/2000] | Loss(BCE): 0.0558
# Epoch [1992/2000] | Loss(BCE): 0.0560
# Epoch [1993/2000] | Loss(BCE): 0.0548
# Epoch [1994/2000] | Loss(BCE): 0.0451
# Epoch [1995/2000] | Loss(BCE): 0.0553
# Epoch [1996/2000] | Loss(BCE): 0.0502
# Epoch [1997/2000] | Loss(BCE): 0.0507
# Epoch [1998/2000] | Loss(BCE): 0.0554
# Epoch [1999/2000] | Loss(BCE): 0.0556
# Epoch [2000/2000] | Loss(BCE): 0.0473

# %%
with torch.no_grad():
  y_hat = model(tensor_test)
  y_hat = (y_hat > 0.5).float()
  y_hat = y_hat.squeeze().numpy().astype(int)
y_hat = pd.DataFrame(y_hat)

summarize = pd.concat([id_test, y_hat], axis=1)
summarize.columns = ['id', 'Class']
summarize.to_csv('My_Answer_data.csv', index=False)
print(summarize['Class'].unique())
summarize
# Out:
# [0 1]
#         id  Class
# 0        0      0
# 1        1      0
# 2        2      0
# 3        3      1
# 4        4      0
# ...    ...    ...
# 7483  7483      0
# 7484  7484      0
# 7485  7485      0
# 7486  7486      0
# 7487  7487      1
#
# [7488 rows x 2 columns]
