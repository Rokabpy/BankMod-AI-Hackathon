# %%
# !pip install opendatasets
# import opendatasets as od
# od.download("https://www.kaggle.com/competitions/cpe-ai-hackathon-2025-medical-image-classification")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
train = pd.read_csv("/content/cpe-ai-hackathon-2025-medical-image-classification/liver-fibrosis-severity-prediction/train.csv")
final = pd.read_csv("/content/cpe-ai-hackathon-2025-medical-image-classification/liver-fibrosis-severity-prediction/test.csv")
train = train.drop(columns=['subject'])
train = train.rename(columns={
    'image_name' : 'img',
    'SWE fibrosis stage' : 'stage',
    'TE result' : 'TE'
})

id_final = final.ID
final = final.drop(columns=['ID'])
final = final.rename(columns={
    'image_id' : 'img',
    'SWE fibrosis stage' : 'stage',
    'TE result' : 'TE'
})

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   img     334 non-null    object
#  1   view    334 non-null    object
#  2   stage   334 non-null    object
#  3   TE      334 non-null    object
# dtypes: object(4)
# memory usage: 10.6+ KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1438 entries, 0 to 1437
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   img      1438 non-null   object
#  1   view     1438 non-null   object
#  2   stage    1438 non-null   object
#  3   TE(kPa)  1438 non-null   float64
#  4   TE       1438 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 56.3+ KB

# %%
np.unique(train['view'])
# Out:
# array(['Intercostal', 'Liver/RK', 'Subcostal_hepatic_vein'], dtype=object)

# %%
np.unique(train['stage'])
# Out:
# array(['-', 'F0-1', 'F2', 'F2 ', 'F3', 'F4'], dtype=object)

# %%
np.unique(train['TE'])
# Out:
# array(['F0', 'F1', 'F2', 'F3', 'F4'], dtype=object)

# %%
train = train.drop(columns='img')

# %%
y_train = train['TE(kPa)']
x_train = train.drop(columns='TE(kPa)')

# %%
x_train
# Out:
#                         view stage  TE
# 0                Intercostal     -  F2
# 1                   Liver/RK  F0-1  F0
# 2     Subcostal_hepatic_vein  F0-1  F0
# 3                   Liver/RK  F0-1  F0
# 4                Intercostal  F0-1  F1
# ...                      ...   ...  ..
# 1433             Intercostal  F0-1  F0
# 1434                Liver/RK  F0-1  F0
# 1435                Liver/RK  F0-1  F1
# 1436             Intercostal  F0-1  F1
# 1437  Subcostal_hepatic_vein  F0-1  F1
#
# [1438 rows x 3 columns]

# %%
final = final.drop(columns='img')
final
# Out:
#                        view stage  TE
# 0               Intercostal     -  F0
# 1    Subcostal_hepatic_vein    F2  F3
# 2               Intercostal    F2  F3
# 3                  Liver/RK    F2  F3
# 4    Subcostal_hepatic_vein  F0-1  F0
# ..                      ...   ...  ..
# 329             Intercostal  F0-1  F4
# 330  Subcostal_hepatic_vein  F0-1  F4
# 331  Subcostal_hepatic_vein  F0-1  F0
# 332             Intercostal  F0-1  F0
# 333                Liver/RK  F0-1  F0
#
# [334 rows x 3 columns]

# %%
x_train['stage'] = x_train['stage'].str.strip().map({
    '-' : 0,
    'F0-1' : 1,
    'F2' : 2,
    'F3' : 3,
    'F4' : 4
})

x_train['TE'] = x_train['TE'].map({
    'F0' : 0,
    'F1' : 1,
    'F2' : 2,
    'F3' : 3,
    'F4' : 4
})

x_train = pd.get_dummies(x_train, columns=['view'], dtype=int)

final['stage'] = final['stage'].str.strip().map({
    '-' : 0,
    'F0-1' : 1,
    'F2' : 2,
    'F3' : 3,
    'F4' : 4
})

final['TE'] = final['TE'].map({
    'F0' : 0,
    'F1' : 1,
    'F2' : 2,
    'F3' : 3,
    'F4' : 4
})

final = pd.get_dummies(final, columns=['view'], dtype=int)

# %%
x_train = x_train.values.astype(np.float32)
y_train = y_train.values.astype(np.float32).reshape(-1, 1)
tensor_x_train = torch.tensor(x_train)
tensor_y_train = torch.tensor(y_train)

final = final.values.astype(np.float32)
tensor_final = torch.tensor(final)

# %%
class neural_network(nn.Module):
    def __init__(self, input_dim, hidden_dims=[256, 128, 64, 32], dropout_rate=0.3):
        super(neural_network, self).__init__()

        self.input_bn = nn.BatchNorm1d(input_dim)
        layers = []
        in_dim = input_dim

        for h_dim in hidden_dims:
            layers.append(Block(in_dim, h_dim, dropout_rate))
            in_dim = h_dim

        self.layers = nn.Sequential(*layers)
        self.output = nn.Linear(in_dim, 1)
        self.apply(self._init_weights)

    def forward(self, x):
        x = self.input_bn(x)
        x = self.layers(x)
        x = self.output(x)
        return x

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            nn.init.kaiming_normal_(m.weight, nonlinearity='leaky_relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)

class Block(nn.Module):
    def __init__(self, in_dim, out_dim, dropout_rate):
        super(Block, self).__init__()
        self.fc = nn.Linear(in_dim, out_dim)
        self.bn = nn.BatchNorm1d(out_dim)
        self.act = nn.LeakyReLU(negative_slope=0.1)
        self.drop = nn.Dropout(dropout_rate)
        self.residual = (in_dim == out_dim)

    def forward(self, x):
        identity = x
        out = self.fc(x)
        out = self.bn(out)
        out = self.act(out)
        out = self.drop(out)
        if self.residual:
            out = out + identity * 0.5
        return out

# %%
model = neural_network(x_train.shape[1])
error = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5)

epoch = 3000
for i in range(epoch):
    model.train()
    y_hat = model(tensor_x_train)
    loss = error(y_hat, tensor_y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (i + 1) % 10 == 0:
        print(f"Epoch [{i+1}/{epoch}] | Loss(MSE): {loss.item():.4f}")
# Out:
# Epoch [10/3000] | Loss(MSE): 21.2621
# Epoch [20/3000] | Loss(MSE): 9.4891
# Epoch [30/3000] | Loss(MSE): 6.5132
# Epoch [40/3000] | Loss(MSE): 6.6678
# Epoch [50/3000] | Loss(MSE): 5.8893
# Epoch [60/3000] | Loss(MSE): 5.4632
# Epoch [70/3000] | Loss(MSE): 5.9787
# Epoch [80/3000] | Loss(MSE): 5.2920
# Epoch [90/3000] | Loss(MSE): 5.1343
# Epoch [100/3000] | Loss(MSE): 5.4049
# Epoch [110/3000] | Loss(MSE): 4.7944
# Epoch [120/3000] | Loss(MSE): 5.5572
# Epoch [130/3000] | Loss(MSE): 5.2900
# Epoch [140/3000] | Loss(MSE): 4.8570
# Epoch [150/3000] | Loss(MSE): 5.0567
# Epoch [160/3000] | Loss(MSE): 5.1593
# Epoch [170/3000] | Loss(MSE): 4.7187
# Epoch [180/3000] | Loss(MSE): 5.3839
# Epoch [190/3000] | Loss(MSE): 5.0998
# Epoch [200/3000] | Loss(MSE): 4.9794
# Epoch [210/3000] | Loss(MSE): 4.7999
# Epoch [220/3000] | Loss(MSE): 4.8208
# Epoch [230/3000] | Loss(MSE): 4.4727
# Epoch [240/3000] | Loss(MSE): 4.3294
# Epoch [250/3000] | Loss(MSE): 4.7686
# Epoch [260/3000] | Loss(MSE): 4.4819
# Epoch [270/3000] | Loss(MSE): 4.6068
# Epoch [280/3000] | Loss(MSE): 4.6512
# Epoch [290/3000] | Loss(MSE): 4.6724
# Epoch [300/3000] | Loss(MSE): 4.4823
# Epoch [310/3000] | Loss(MSE): 4.2909
# Epoch [320/3000] | Loss(MSE): 4.7226
# Epoch [330/3000] | Loss(MSE): 4.5893
# Epoch [340/3000] | Loss(MSE): 3.9917
# Epoch [350/3000] | Loss(MSE): 4.3031
# Epoch [360/3000] | Loss(MSE): 4.5211
# Epoch [370/3000] | Loss(MSE): 4.6423
# Epoch [380/3000] | Loss(MSE): 4.3619
# Epoch [390/3000] | Loss(MSE): 4.3610
# Epoch [400/3000] | Loss(MSE): 4.2550
# Epoch [410/3000] | Loss(MSE): 4.6768
# Epoch [420/3000] | Loss(MSE): 4.3113
# Epoch [430/3000] | Loss(MSE): 4.1902
# Epoch [440/3000] | Loss(MSE): 3.8992
# Epoch [450/3000] | Loss(MSE): 4.2184
# Epoch [460/3000] | Loss(MSE): 4.7120
# Epoch [470/3000] | Loss(MSE): 4.4492
# Epoch [480/3000] | Loss(MSE): 3.8317
# Epoch [490/3000] | Loss(MSE): 4.1565
# Epoch [500/3000] | Loss(MSE): 3.8103
# Epoch [510/3000] | Loss(MSE): 4.5655
# Epoch [520/3000] | Loss(MSE): 3.9833
# Epoch [530/3000] | Loss(MSE): 4.5150
# Epoch [540/3000] | Loss(MSE): 3.9930
# Epoch [550/3000] | Loss(MSE): 4.5966
# Epoch [560/3000] | Loss(MSE): 4.6728
# Epoch [570/3000] | Loss(MSE): 4.2419
# Epoch [580/3000] | Loss(MSE): 4.1699
# Epoch [590/3000] | Loss(MSE): 4.5251
# Epoch [600/3000] | Loss(MSE): 4.4678
# Epoch [610/3000] | Loss(MSE): 4.3268
# Epoch [620/3000] | Loss(MSE): 4.1387
# Epoch [630/3000] | Loss(MSE): 4.2187
# Epoch [640/3000] | Loss(MSE): 4.5635
# Epoch [650/3000] | Loss(MSE): 4.2977
# Epoch [660/3000] | Loss(MSE): 4.1316
# Epoch [670/3000] | Loss(MSE): 4.2791
# Epoch [680/3000] | Loss(MSE): 4.0733
# Epoch [690/3000] | Loss(MSE): 4.2458
# Epoch [700/3000] | Loss(MSE): 4.4058
# Epoch [710/3000] | Loss(MSE): 4.4131
# Epoch [720/3000] | Loss(MSE): 4.3798
# Epoch [730/3000] | Loss(MSE): 4.1880
# Epoch [740/3000] | Loss(MSE): 4.1738
# Epoch [750/3000] | Loss(MSE): 4.0627
# Epoch [760/3000] | Loss(MSE): 4.1977
# Epoch [770/3000] | Loss(MSE): 3.8652
# Epoch [780/3000] | Loss(MSE): 4.0343
# Epoch [790/3000] | Loss(MSE): 4.2579
# Epoch [800/3000] | Loss(MSE): 4.0078
# Epoch [810/3000] | Loss(MSE): 3.7797
# Epoch [820/3000] | Loss(MSE): 4.0491
# Epoch [830/3000] | Loss(MSE): 4.5204
# Epoch [840/3000] | Loss(MSE): 3.8686
# Epoch [850/3000] | Loss(MSE): 3.9860
# Epoch [860/3000] | Loss(MSE): 4.1653
# Epoch [870/3000] | Loss(MSE): 4.2649
# Epoch [880/3000] | Loss(MSE): 4.6705
# Epoch [890/3000] | Loss(MSE): 4.4690
# Epoch [900/3000] | Loss(MSE): 4.4477
# Epoch [910/3000] | Loss(MSE): 3.8347
# Epoch [920/3000] | Loss(MSE): 3.7705
# Epoch [930/3000] | Loss(MSE): 4.0000
# Epoch [940/3000] | Loss(MSE): 3.7917
# Epoch [950/3000] | Loss(MSE): 3.9179
# Epoch [960/3000] | Loss(MSE): 4.4088
# Epoch [970/3000] | Loss(MSE): 3.9951
# Epoch [980/3000] | Loss(MSE): 3.9748
# Epoch [990/3000] | Loss(MSE): 3.7096
# Epoch [1000/3000] | Loss(MSE): 3.7742
# Epoch [1010/3000] | Loss(MSE): 3.6238
# Epoch [1020/3000] | Loss(MSE): 3.8528
# Epoch [1030/3000] | Loss(MSE): 3.7380
# Epoch [1040/3000] | Loss(MSE): 3.8500
# Epoch [1050/3000] | Loss(MSE): 3.8635
# Epoch [1060/3000] | Loss(MSE): 4.1814
# Epoch [1070/3000] | Loss(MSE): 3.9161
# Epoch [1080/3000] | Loss(MSE): 4.3689
# Epoch [1090/3000] | Loss(MSE): 3.5813
# Epoch [1100/3000] | Loss(MSE): 4.5458
# Epoch [1110/3000] | Loss(MSE): 3.8426
# Epoch [1120/3000] | Loss(MSE): 4.2164
# Epoch [1130/3000] | Loss(MSE): 3.6509
# Epoch [1140/3000] | Loss(MSE): 4.1754
# Epoch [1150/3000] | Loss(MSE): 3.8612
# Epoch [1160/3000] | Loss(MSE): 3.7716
# Epoch [1170/3000] | Loss(MSE): 3.9778
# Epoch [1180/3000] | Loss(MSE): 3.8426
# Epoch [1190/3000] | Loss(MSE): 4.1859
# Epoch [1200/3000] | Loss(MSE): 3.8558
# Epoch [1210/3000] | Loss(MSE): 4.3461
# Epoch [1220/3000] | Loss(MSE): 4.0984
# Epoch [1230/3000] | Loss(MSE): 3.9976
# Epoch [1240/3000] | Loss(MSE): 3.8933
# Epoch [1250/3000] | Loss(MSE): 4.1882
# Epoch [1260/3000] | Loss(MSE): 3.9484
# Epoch [1270/3000] | Loss(MSE): 4.1513
# Epoch [1280/3000] | Loss(MSE): 3.9949
# Epoch [1290/3000] | Loss(MSE): 4.0148
# Epoch [1300/3000] | Loss(MSE): 3.6380
# Epoch [1310/3000] | Loss(MSE): 3.8817
# Epoch [1320/3000] | Loss(MSE): 3.7752
# Epoch [1330/3000] | Loss(MSE): 3.7490
# Epoch [1340/3000] | Loss(MSE): 4.2847
# Epoch [1350/3000] | Loss(MSE): 4.0680
# Epoch [1360/3000] | Loss(MSE): 3.6181
# Epoch [1370/3000] | Loss(MSE): 3.7205
# Epoch [1380/3000] | Loss(MSE): 3.9634
# Epoch [1390/3000] | Loss(MSE): 3.7761
# Epoch [1400/3000] | Loss(MSE): 3.9902
# Epoch [1410/3000] | Loss(MSE): 3.5365
# Epoch [1420/3000] | Loss(MSE): 3.7240
# Epoch [1430/3000] | Loss(MSE): 4.0669
# Epoch [1440/3000] | Loss(MSE): 3.8263
# Epoch [1450/3000] | Loss(MSE): 4.0484
# Epoch [1460/3000] | Loss(MSE): 3.8020
# Epoch [1470/3000] | Loss(MSE): 3.9864
# Epoch [1480/3000] | Loss(MSE): 4.0103
# Epoch [1490/3000] | Loss(MSE): 3.8438
# Epoch [1500/3000] | Loss(MSE): 3.8772
# Epoch [1510/3000] | Loss(MSE): 3.9164
# Epoch [1520/3000] | Loss(MSE): 3.8673
# Epoch [1530/3000] | Loss(MSE): 3.7395
# Epoch [1540/3000] | Loss(MSE): 3.6189
# Epoch [1550/3000] | Loss(MSE): 4.1275
# Epoch [1560/3000] | Loss(MSE): 3.7759
# Epoch [1570/3000] | Loss(MSE): 3.8853
# Epoch [1580/3000] | Loss(MSE): 3.8411
# Epoch [1590/3000] | Loss(MSE): 3.7080
# Epoch [1600/3000] | Loss(MSE): 3.8197
# Epoch [1610/3000] | Loss(MSE): 3.5859
# Epoch [1620/3000] | Loss(MSE): 3.9003
# Epoch [1630/3000] | Loss(MSE): 3.5222
# Epoch [1640/3000] | Loss(MSE): 3.7390
# Epoch [1650/3000] | Loss(MSE): 4.1028
# Epoch [1660/3000] | Loss(MSE): 3.6625
# Epoch [1670/3000] | Loss(MSE): 3.8516
# Epoch [1680/3000] | Loss(MSE): 3.7320
# Epoch [1690/3000] | Loss(MSE): 4.0197
# Epoch [1700/3000] | Loss(MSE): 3.9252
# Epoch [1710/3000] | Loss(MSE): 4.1205
# Epoch [1720/3000] | Loss(MSE): 3.6072
# Epoch [1730/3000] | Loss(MSE): 3.8489
# Epoch [1740/3000] | Loss(MSE): 3.7822
# Epoch [1750/3000] | Loss(MSE): 3.5725
# Epoch [1760/3000] | Loss(MSE): 4.0406
# Epoch [1770/3000] | Loss(MSE): 3.9398
# Epoch [1780/3000] | Loss(MSE): 3.6248
# Epoch [1790/3000] | Loss(MSE): 3.6498
# Epoch [1800/3000] | Loss(MSE): 3.5445
# Epoch [1810/3000] | Loss(MSE): 3.5082
# Epoch [1820/3000] | Loss(MSE): 3.9724
# Epoch [1830/3000] | Loss(MSE): 3.7383
# Epoch [1840/3000] | Loss(MSE): 3.3566
# Epoch [1850/3000] | Loss(MSE): 3.8903
# Epoch [1860/3000] | Loss(MSE): 3.8419
# Epoch [1870/3000] | Loss(MSE): 3.5286
# Epoch [1880/3000] | Loss(MSE): 4.0008
# Epoch [1890/3000] | Loss(MSE): 3.5829
# Epoch [1900/3000] | Loss(MSE): 3.6006
# Epoch [1910/3000] | Loss(MSE): 3.6744
# Epoch [1920/3000] | Loss(MSE): 4.0521
# Epoch [1930/3000] | Loss(MSE): 3.7122
# Epoch [1940/3000] | Loss(MSE): 3.6636
# Epoch [1950/3000] | Loss(MSE): 4.1555
# Epoch [1960/3000] | Loss(MSE): 4.0783
# Epoch [1970/3000] | Loss(MSE): 4.0443
# Epoch [1980/3000] | Loss(MSE): 3.8027
# Epoch [1990/3000] | Loss(MSE): 3.9665
# Epoch [2000/3000] | Loss(MSE): 4.0594
# Epoch [2010/3000] | Loss(MSE): 3.6657
# Epoch [2020/3000] | Loss(MSE): 3.8866
# Epoch [2030/3000] | Loss(MSE): 3.7274
# Epoch [2040/3000] | Loss(MSE): 3.6866
# Epoch [2050/3000] | Loss(MSE): 3.7270
# Epoch [2060/3000] | Loss(MSE): 4.0804
# Epoch [2070/3000] | Loss(MSE): 4.0952
# Epoch [2080/3000] | Loss(MSE): 3.5755
# Epoch [2090/3000] | Loss(MSE): 3.9080
# Epoch [2100/3000] | Loss(MSE): 3.7686
# Epoch [2110/3000] | Loss(MSE): 3.6144
# Epoch [2120/3000] | Loss(MSE): 3.4478
# Epoch [2130/3000] | Loss(MSE): 4.0051
# Epoch [2140/3000] | Loss(MSE): 3.6036
# Epoch [2150/3000] | Loss(MSE): 3.6656
# Epoch [2160/3000] | Loss(MSE): 3.4379
# Epoch [2170/3000] | Loss(MSE): 3.7804
# Epoch [2180/3000] | Loss(MSE): 3.7905
# Epoch [2190/3000] | Loss(MSE): 3.6492
# Epoch [2200/3000] | Loss(MSE): 3.8328
# Epoch [2210/3000] | Loss(MSE): 3.6375
# Epoch [2220/3000] | Loss(MSE): 3.4879
# Epoch [2230/3000] | Loss(MSE): 3.8551
# Epoch [2240/3000] | Loss(MSE): 3.6912
# Epoch [2250/3000] | Loss(MSE): 3.4436
# Epoch [2260/3000] | Loss(MSE): 3.6551
# Epoch [2270/3000] | Loss(MSE): 4.0108
# Epoch [2280/3000] | Loss(MSE): 3.5129
# Epoch [2290/3000] | Loss(MSE): 3.6828
# Epoch [2300/3000] | Loss(MSE): 3.6757
# Epoch [2310/3000] | Loss(MSE): 3.4564
# Epoch [2320/3000] | Loss(MSE): 3.8390
# Epoch [2330/3000] | Loss(MSE): 3.7429
# Epoch [2340/3000] | Loss(MSE): 3.5225
# Epoch [2350/3000] | Loss(MSE): 3.4259
# Epoch [2360/3000] | Loss(MSE): 3.5386
# Epoch [2370/3000] | Loss(MSE): 3.7144
# Epoch [2380/3000] | Loss(MSE): 3.8834
# Epoch [2390/3000] | Loss(MSE): 3.4022
# Epoch [2400/3000] | Loss(MSE): 3.7274
# Epoch [2410/3000] | Loss(MSE): 3.7335
# Epoch [2420/3000] | Loss(MSE): 3.3625
# Epoch [2430/3000] | Loss(MSE): 3.7047
# Epoch [2440/3000] | Loss(MSE): 3.7567
# Epoch [2450/3000] | Loss(MSE): 3.6045
# Epoch [2460/3000] | Loss(MSE): 3.8894
# Epoch [2470/3000] | Loss(MSE): 3.7676
# Epoch [2480/3000] | Loss(MSE): 3.6697
# Epoch [2490/3000] | Loss(MSE): 3.4661
# Epoch [2500/3000] | Loss(MSE): 3.8417
# Epoch [2510/3000] | Loss(MSE): 3.9092
# Epoch [2520/3000] | Loss(MSE): 3.9325
# Epoch [2530/3000] | Loss(MSE): 3.8282
# Epoch [2540/3000] | Loss(MSE): 3.6432
# Epoch [2550/3000] | Loss(MSE): 3.7696
# Epoch [2560/3000] | Loss(MSE): 3.4679
# Epoch [2570/3000] | Loss(MSE): 3.7840
# Epoch [2580/3000] | Loss(MSE): 3.7206
# Epoch [2590/3000] | Loss(MSE): 3.8302
# Epoch [2600/3000] | Loss(MSE): 3.6014
# Epoch [2610/3000] | Loss(MSE): 3.9439
# Epoch [2620/3000] | Loss(MSE): 3.4353
# Epoch [2630/3000] | Loss(MSE): 3.7168
# Epoch [2640/3000] | Loss(MSE): 3.3942
# Epoch [2650/3000] | Loss(MSE): 3.4624
# Epoch [2660/3000] | Loss(MSE): 3.8858
# Epoch [2670/3000] | Loss(MSE): 3.4622
# Epoch [2680/3000] | Loss(MSE): 3.4983
# Epoch [2690/3000] | Loss(MSE): 3.7600
# Epoch [2700/3000] | Loss(MSE): 3.9513
# Epoch [2710/3000] | Loss(MSE): 3.5900
# Epoch [2720/3000] | Loss(MSE): 3.7479
# Epoch [2730/3000] | Loss(MSE): 3.6314
# Epoch [2740/3000] | Loss(MSE): 3.5294
# Epoch [2750/3000] | Loss(MSE): 3.7012
# Epoch [2760/3000] | Loss(MSE): 3.3355
# Epoch [2770/3000] | Loss(MSE): 3.5431
# Epoch [2780/3000] | Loss(MSE): 3.7534
# Epoch [2790/3000] | Loss(MSE): 3.8313
# Epoch [2800/3000] | Loss(MSE): 3.8702
# Epoch [2810/3000] | Loss(MSE): 3.4842
# Epoch [2820/3000] | Loss(MSE): 3.4596
# Epoch [2830/3000] | Loss(MSE): 3.8863
# Epoch [2840/3000] | Loss(MSE): 3.5678
# Epoch [2850/3000] | Loss(MSE): 3.5145
# Epoch [2860/3000] | Loss(MSE): 3.6393
# Epoch [2870/3000] | Loss(MSE): 3.8149
# Epoch [2880/3000] | Loss(MSE): 3.7355
# Epoch [2890/3000] | Loss(MSE): 3.7183
# Epoch [2900/3000] | Loss(MSE): 3.3173
# Epoch [2910/3000] | Loss(MSE): 3.4754
# Epoch [2920/3000] | Loss(MSE): 3.6408
# Epoch [2930/3000] | Loss(MSE): 3.5903
# Epoch [2940/3000] | Loss(MSE): 3.6730
# Epoch [2950/3000] | Loss(MSE): 3.3399
# Epoch [2960/3000] | Loss(MSE): 3.7221
# Epoch [2970/3000] | Loss(MSE): 3.5132
# Epoch [2980/3000] | Loss(MSE): 3.7483
# Epoch [2990/3000] | Loss(MSE): 3.7653
# Epoch [3000/3000] | Loss(MSE): 3.6021

# %%
with torch.no_grad():
  y_hat = model(tensor_final)
y_hat = pd.DataFrame(y_hat)
summarize = pd.concat([id_final, y_hat], axis=1)
summarize.columns = ['ID', 'TE(kPa)']
summarize.to_csv('My_Answer.csv', index=False)
summarize
# Out:
#       ID    TE(kPa)
# 0      1   4.623334
# 1      2   8.907242
# 2      3   9.313368
# 3      4   8.869608
# 4      5   4.328938
# ..   ...        ...
# 329  330  22.027388
# 330  331  15.265818
# 331  332   4.354945
# 332  333   4.317220
# 333  334   4.188297
#
# [334 rows x 2 columns]
